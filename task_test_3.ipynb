# %%
import itertools
from optlang import Constraint, Variable
import pandas as pd
import cobra.flux_analysis
from cobra import Metabolite, Reaction, Model
import time
import numpy as np
from functools import partial
from src.mp_functions import combinations_subset, parallelize_dataframe, knockout_FBA, knockout_FBA_w_tasks

from functools import partial
from src.met_task_functions import get_met_ids, constrain_model, create_reactions


"""A mess of a document with different code cells.
Good to to use for any testing that involves the Recon3D model as it takes some time to load in."""

start_time = time.time()
model_file_path = 'C:/Users/Sigve/Genome_Data/Human1/Human1_GEM/GTEx/brain.xml'
model = cobra.io.read_sbml_model(model_file_path)

model_list = constrain_model(model, ALLMETSIN=True)

end_time = time.time()
print('Model load and preparation time: %.6f seconds' % (end_time - start_time))
# Out:
# Read LP format model from file C:\Users\Sigve\AppData\Local\Temp\tmpdcj61irn.lp
# Reading time = 0.07 seconds
# : 5482 rows, 15138 columns, 66608 nonzeros
# Read LP format model from file C:\Users\Sigve\AppData\Local\Temp\tmplulq1_db.lp
# Reading time = 0.07 seconds
# : 5482 rows, 15138 columns, 66608 nonzeros
# Read LP format model from file C:\Users\Sigve\AppData\Local\Temp\tmpx8qd_s0h.lp
# Reading time = 0.06 seconds
# : 5482 rows, 15138 columns, 66608 nonzeros
# Model load and preparation time: 77.078590 seconds

# %%
def tasks_test(task_list: list, model_list: list, gene_ids: list) -> list:
    """Performs knockout FBA and checks tasks for the knockout."""
    with model_list[0]:
        for gene_id in gene_ids:
            try:
                model_list[0].genes.get_by_id(gene_id).knock_out()
            except KeyError:
                return gene_id + ' not in model.'
        res = [model_list[0].slim_optimize()]

    for task in task_list:
        t_model = model_list[task[3]]

        with t_model:
            for subset in [task[0], task[1]]:
                for rx in subset:
                    if rx == 'ALLMETSIN':
                        # Adds boundary metabolites for other reactions when ALLMETSIN is used
                        for r in subset[1:]:
                            for m2 in r.metabolites:
                                for r2 in m2.reactions:
                                    if r2.boundary and r2.id != r.id:
                                        r2.add_metabolites({Metabolite(
                                                            m2.id[:-4] + 'x[x]',
                                                            formula=m2.formula,
                                                            name=' '.join(m2.name.split(' ')[:-1]) + ' [Boundary]',
                                                            compartment='x'): 1})
                        continue
                    t_model.add_reaction(rx)

            if task[2] != 'nan':
                t_model.add_reaction(task[2])

            for gene_id in gene_ids:
                t_model.genes.get_by_id(gene_id).knock_out()


            if t_model.slim_optimize() is None:
                res += [0]
            else:
                res += [1]


    return res

# %%
def create_constraints(tasks: pd.DataFrame) -> pd.DataFrame:
    # Producing reactions based on tasks
    rx_list = []
    in_list = []
    out_list = []

    for ind, data in tasks.iterrows():

        for i, name, ml, lbs, ubs in zip([1, -1], ['in', 'out'], [data.inputs, data.outputs], [data.LBin, data.LBout],
                                         [data.UBin, data.UBout]):

            rxl = []
            for j, m, lb, ub in zip(range(len(ml)), ml, lbs, ubs):

                if m[:9] == 'ALLMETSIN':
                    rxl.append('ALLMETSIN')
                    continue
                if i == -1:
                    rxl.append(Variable(data['met_ids'][m].id, lb=float(lb), ub=float(ub)))
                else:
                    rxl.append(Variable(data['met_ids'][m].id, lb=-float(ub), ub=-float(lb)))

                """
                rx = Reaction('ess_{0}_{1}_{2}'.format(ind+1, name, j))
                rx.add_metabolites({data['met_ids'][m]: i})
                rx.lower_bound = float(lb)
                rx.upper_bound = float(ub)
                rxl.append(rx)"""

            if name == 'in':
                in_list.append(rxl)
            else:
                out_list.append(rxl)

        if data.equations != 'nan':
            t = [[data['met_ids'][subsub] for subsub in sub.split(' ') if len(subsub) > 1] for sub in data.equations.split('=')]
            d = {}

            for i, ml in zip([-1, 1], t):
                for m in ml:
                    d[m] = i

            rx = Reaction('ess_{0}'.format(ind + 1))
            rx.add_metabolites(d)
            rx.lower_bound = float(data.LBequ)
            rx.upper_bound = float(data.UBequ)
            rx.name = data.description

            rx_list.append(rx)

        else:
            rx_list.append('nan')

    return pd.DataFrame(list(zip(in_list, out_list, rx_list, tasks['model_num'].tolist())), columns=['in_rx', 'out_rx', 'equ', 'model_num'])

# %%
# Read and format task data
tasks_df = pd.read_table('C:/Users/Sigve/Genome_Data/Human1/Human1_GEM/tasks/essential_tasks.tsv')

for b in ['LBin', 'LBout', 'UBin', 'UBout']:
    tasks_df[b] = tasks_df[b].apply(lambda x: x.split(','))

for put in ['inputs', 'outputs']:
    tasks_df[put] = tasks_df[put].apply(lambda x: [e + ']' for e in x[1:-1].split(']')][0:-1])

tasks_df['equations'] = tasks_df['equations'].apply(str)

tasks_df[['met_ids', 'model_num']] = tasks_df.apply(partial(get_met_ids, model_list), axis=1, result_type='expand')

tasks_df = create_constraints(tasks_df)

task_list = list(tasks_df.values.tolist())
print(task_list)
# Out:
# [[[-1000.0 <= m02630s[s] <= -0.0, -1000.0 <= m01965s[s] <= -0.0], [0.0 <= m02040s[s] <= 1000.0, 0.0 <= m01596s[s] <= 1000.0], <Reaction ess_1 at 0x12b11c01760>, 1], [[-1000.0 <= m02630s[s] <= -0.0, -1000.0 <= m01965s[s] <= -0.0], [0.0 <= m02040s[s] <= 1000.0, 0.0 <= m01596s[s] <= 1000.0], <Reaction ess_2 at 0x12b11a220a0>, 1], [[-1000.0 <= m02630s[s] <= -0.0, -1000.0 <= m01965s[s] <= -0.0], [0.0 <= m02040s[s] <= 1000.0, 0.0 <= m01596s[s] <= 1000.0], <Reaction ess_3 at 0x12b118d3e20>, 1], [[-1000.0 <= m02630s[s] <= -0.0, -1000.0 <= m01965s[s] <= -0.0], [0.0 <= m02040s[s] <= 1000.0, 0.0 <= m01596s[s] <= 1000.0], <Reaction ess_4 at 0x12b0ff27790>, 1], [[-1000.0 <= m02630s[s] <= -0.0, -1000.0 <= m01965s[s] <= -0.0, -1000.0 <= m02578s[s] <= -0.0, -1000.0 <= m02751s[s] <= -0.0], [0.0 <= m02040s[s] <= 1000.0, 0.0 <= m01596s[s] <= 1000.0, 1.0 <= m01371c[c] <= 1000.0], <Reaction ess_5 at 0x12b11099fd0>, 1], [[-1000.0 <= m02630s[s] <= -0.0, -1000.0 <= m01965s[s] <= -0.0, -1000.0 <= m02578s[s] <= -0.0, -1000.0 <= m02751s[s] <= -0.0], [0.0 <= m02040s[s] <= 1000.0, 0.0 <= m01596s[s] <= 1000.0, 1.0 <= m01623c[c] <= 1000.0], <Reaction ess_6 at 0x12b11c3f700>, 1], [[-1000.0 <= m02630s[s] <= -0.0, -1000.0 <= m01965s[s] <= -0.0, -1000.0 <= m02578s[s] <= -0.0, -1000.0 <= m02751s[s] <= -0.0], [0.0 <= m02040s[s] <= 1000.0, 0.0 <= m01596s[s] <= 1000.0, 1.0 <= m02034c[c] <= 1000.0], <Reaction ess_7 at 0x12b11c01af0>, 1], [[-1000.0 <= m02630s[s] <= -0.0, -1000.0 <= m01965s[s] <= -0.0, -1000.0 <= m02578s[s] <= -0.0, -1000.0 <= m02751s[s] <= -0.0], [0.0 <= m02040s[s] <= 1000.0, 0.0 <= m01596s[s] <= 1000.0, 1.0 <= m03130c[c] <= 1000.0], <Reaction ess_8 at 0x12b11cbaeb0>, 1], [[-1000.0 <= m02630s[s] <= -0.0, -1000.0 <= m01965s[s] <= -0.0, -1000.0 <= m02578s[s] <= -0.0, -1000.0 <= m02751s[s] <= -0.0], [0.0 <= m02040s[s] <= 1000.0, 0.0 <= m01596s[s] <= 1000.0, 1.0 <= m01642c[c] <= 1000.0], <Reaction ess_9 at 0x12b1149ea60>, 1], [[-1000.0 <= m02630s[s] <= -0.0, -1000.0 <= m01965s[s] <= -0.0, -1000.0 <= m02578s[s] <= -0.0, -1000.0 <= m02751s[s] <= -0.0], [0.0 <= m02040s[s] <= 1000.0, 0.0 <= m01596s[s] <= 1000.0, 1.0 <= m01645c[c] <= 1000.0], <Reaction ess_10 at 0x12b110cb3a0>, 1], [[-1000.0 <= m02630s[s] <= -0.0, -1000.0 <= m01965s[s] <= -0.0, -1000.0 <= m02578s[s] <= -0.0, -1000.0 <= m02751s[s] <= -0.0], [0.0 <= m02040s[s] <= 1000.0, 0.0 <= m01596s[s] <= 1000.0, 1.0 <= m01688c[c] <= 1000.0], <Reaction ess_11 at 0x12b11ba98e0>, 1], [[-1000.0 <= m02630s[s] <= -0.0, -1000.0 <= m01965s[s] <= -0.0, -1000.0 <= m02578s[s] <= -0.0, -1000.0 <= m02751s[s] <= -0.0], [0.0 <= m02040s[s] <= 1000.0, 0.0 <= m01596s[s] <= 1000.0, 1.0 <= m01753c[c] <= 1000.0], <Reaction ess_12 at 0x12b110b5eb0>, 1], [[-1.0 <= m02125s[s] <= -1.0], [1.0 <= m02125c[c] <= 1000.0], 'nan', 1], [[-1.0 <= m02184s[s] <= -1.0], [1.0 <= m02184c[c] <= 1000.0], 'nan', 1], [[-1.0 <= m02360s[s] <= -1.0], [1.0 <= m02360c[c] <= 1000.0], 'nan', 1], [[-1.0 <= m02426s[s] <= -1.0], [1.0 <= m02426c[c] <= 1000.0], 'nan', 1], [[-1.0 <= m02471s[s] <= -1.0], [1.0 <= m02471c[c] <= 1000.0], 'nan', 1], [[-1.0 <= m02724s[s] <= -1.0], [1.0 <= m02724c[c] <= 1000.0], 'nan', 1], [[-1.0 <= m02993s[s] <= -1.0], [1.0 <= m02993c[c] <= 1000.0], 'nan', 1], [[-1.0 <= m03089s[s] <= -1.0], [1.0 <= m03089c[c] <= 1000.0], 'nan', 1], [[-1.0 <= m03135s[s] <= -1.0], [1.0 <= m03135c[c] <= 1000.0], 'nan', 1], [[-1000.0 <= m02630s[s] <= -0.0, -1000.0 <= m01965s[s] <= -0.0, -1000.0 <= m02751s[s] <= -0.0], [1.0 <= m00913c[c] <= 1000.0, 0.0 <= m01596s[s] <= 1000.0, 0.0 <= m02040s[s] <= 1000.0], 'nan', 1], [[-1000.0 <= m02630s[s] <= -0.0, -1000.0 <= m01965s[s] <= -0.0], [0.0 <= m01596s[s] <= 1000.0, 0.0 <= m02040s[s] <= 1000.0], <Reaction ess_23 at 0x12b11a18190>, 1], [[-1000.0 <= m02630s[s] <= -0.0, -1000.0 <= m01965s[s] <= -0.0], [1.0 <= m01306m[m] <= 1000.0, 0.0 <= m01596s[s] <= 1000.0, 0.0 <= m02040s[s] <= 1000.0], 'nan', 1], [[-1000.0 <= m02630s[s] <= -0.0, -1000.0 <= m01965s[s] <= -0.0, -1000.0 <= m02751s[s] <= -0.0], [1.0 <= m01785c[c] <= ...

# %%
# Read test data
test_data = pd.read_csv('C:/Users/Sigve/Genome_Data/results/model_tests/test_data.csv')
test_data['pass/fail'] = test_data.values[:, 4:].tolist()
test_data = test_data[['phewas_code', 'gene_ids', 'solution', 'pass/fail']]
test_data['gene_ids'] = test_data['gene_ids'].apply(lambda x: x.split(','))
print(test_data.head())

# Reduce number of entries
test_data = test_data.iloc[:10, :]

# %%
g = ['ENSG00000100030', 'ENSG00000197375']
# %load_ext line_profiler
# %lprun -f tasks_test tasks_test(task_list, model_list, g)

# %%
start_time = time.time()

test_data['results'] = test_data['gene_ids'].apply(partial(tasks_test, task_list, model_list))

end_time = time.time()
print('FBA runtime: %.6f seconds' % (end_time - start_time))

# %%
# Data comparison

result_df = test_data.copy()

print(result_df.shape[0])


result_df['main_obj'] = result_df['results'].apply(lambda x: x[0])
result_df['results'] = result_df['results'].apply(lambda x: x[1:])

result_df['comparison'] = result_df[['pass/fail', 'results']].apply(lambda x: any([False if i == j else True for i, j in zip(x[0], x[1])]), axis=1)
error_df = result_df[result_df['comparison']]
print('Number of detected errors: ' + str(error_df.shape[0]))

# %%
t_model = model_list[1]

with t_model:
    tasks = task_list[0][0] + task_list[0][1]
    t_model.add_cons_vars(task_list[0][0:1])
    t_model.add_reaction(task_list[0][2])
    print(t_model.slim_optimize())

    variables = t_model.variables
    for v in variables:
        print(v)
# Out:
# nan
# 0.0 <= biomass_human <= 1000.0
# 0.0 <= biomass_human_reverse_fb2f2 <= 0.0
# 0.0 <= HMR_0241 <= 1000.0
# 0.0 <= HMR_0241_reverse_40008 <= 1000.0
# 0.0 <= HMR_0242 <= 1000.0
# 0.0 <= HMR_0242_reverse_0a022 <= 0.0
# 0.0 <= HMR_0240 <= 1000.0
# 0.0 <= HMR_0240_reverse_6e2eb <= 0.0
# 0.0 <= HMR_0243 <= 1000.0
# 0.0 <= HMR_0243_reverse_abdec <= 0.0
# 0.0 <= HMR_10033 <= 1000.0
# 0.0 <= HMR_10033_reverse_aa17a <= 1000.0
# 0.0 <= HMR_2955 <= 1000.0
# 0.0 <= HMR_2955_reverse_6e373 <= 1000.0
# 0.0 <= HMR_3695 <= 1000.0
# 0.0 <= HMR_3695_reverse_d3d9b <= 0.0
# 0.0 <= HMR_0015 <= 1000.0
# 0.0 <= HMR_0015_reverse_d37e4 <= 0.0
# 0.0 <= EX_M00003[e] <= 1000.0
# 0.0 <= EX_M00003[e]_reverse_3fde7 <= 1000.0
# 0.0 <= HMR_2288 <= 1000.0
# 0.0 <= HMR_2288_reverse_8ee17 <= 0.0
# 0.0 <= HMR_2648 <= 1000.0
# 0.0 <= HMR_2648_reverse_8a135 <= 1000.0
# 0.0 <= HMR_0497 <= 1000.0
# 0.0 <= HMR_0497_reverse_0f0fc <= 0.0
# 0.0 <= HMR_0553 <= 1000.0
# 0.0 <= HMR_0553_reverse_00e01 <= 0.0
# 0.0 <= HMR_2650 <= 1000.0
# 0.0 <= HMR_2650_reverse_06283 <= 1000.0
# 0.0 <= HMR_3396 <= 1000.0
# 0.0 <= HMR_3396_reverse_07050 <= 0.0
# 0.0 <= HMR_2814 <= 1000.0
# 0.0 <= HMR_2814_reverse_7b040 <= 1000.0
# 0.0 <= HMR_3636 <= 1000.0
# 0.0 <= HMR_3636_reverse_72b88 <= 0.0
# 0.0 <= HMR_0323 <= 1000.0
# 0.0 <= HMR_0323_reverse_1a0ee <= 1000.0
# 0.0 <= HMR_2356 <= 1000.0
# 0.0 <= HMR_2356_reverse_d5bee <= 0.0
# 0.0 <= HMR_0324 <= 1000.0
# 0.0 <= HMR_0324_reverse_c5eb0 <= 0.0
# 0.0 <= HMR_2708 <= 1000.0
# 0.0 <= HMR_2708_reverse_96287 <= 1000.0
# 0.0 <= HMR_0516 <= 1000.0
# 0.0 <= HMR_0516_reverse_e507c <= 0.0
# 0.0 <= HMR_2710 <= 1000.0
# 0.0 <= HMR_2710_reverse_a4b7c <= 1000.0
# 0.0 <= HMR_3416 <= 1000.0
# 0.0 <= HMR_3416_reverse_1253f <= 0.0
# 0.0 <= HMR_2975 <= 1000.0
# 0.0 <= HMR_2975_reverse_b9970 <= 1000.0
# 0.0 <= HMR_2856 <= 1000.0
# 0.0 <= HMR_2856_reverse_d648e <= 1000.0
# 0.0 <= HMR_3655 <= 1000.0
# 0.0 <= HMR_3655_reverse_f8889 <= 0.0
# 0.0 <= HMR_0293 <= 1000.0
# 0.0 <= HMR_0293_reverse_71abe <= 1000.0
# 0.0 <= HMR_2311 <= 1000.0
# 0.0 <= HMR_2311_reverse_058f5 <= 0.0
# 0.0 <= HMR_2315 <= 1000.0
# 0.0 <= HMR_2315_reverse_b04fb <= 0.0
# 0.0 <= HMR_0294 <= 1000.0
# 0.0 <= HMR_0294_reverse_2e9d0 <= 0.0
# 0.0 <= HMR_2684 <= 1000.0
# 0.0 <= HMR_2684_reverse_4b2b1 <= 1000.0
# 0.0 <= HMR_0509 <= 1000.0
# 0.0 <= HMR_0509_reverse_2bb8e <= 0.0
# 0.0 <= HMR_2686 <= 1000.0
# 0.0 <= HMR_2686_reverse_8c133 <= 1000.0
# 0.0 <= HMR_3221 <= 1000.0
# 0.0 <= HMR_3221_reverse_31d45 <= 0.0
# 0.0 <= HMR_3222 <= 1000.0
# 0.0 <= HMR_3222_reverse_063b1 <= 0.0
# 0.0 <= HMR_3337 <= 1000.0
# 0.0 <= HMR_3337_reverse_9fd2d <= 0.0
# 0.0 <= HMR_3338 <= 1000.0
# 0.0 <= HMR_3338_reverse_564a2 <= 0.0
# 0.0 <= HMR_2967 <= 1000.0
# 0.0 <= HMR_2967_reverse_a18dd <= 1000.0
# 0.0 <= HMR_2840 <= 1000.0
# 0.0 <= HMR_2840_reverse_276b6 <= 1000.0
# 0.0 <= HMR_3648 <= 1000.0
# 0.0 <= HMR_3648_reverse_ebdd7 <= 0.0
# 0.0 <= RE3225R <= 1000.0
# 0.0 <= RE3225R_reverse_76d3f <= 0.0
# 0.0 <= RE3229R <= 1000.0
# 0.0 <= RE3229R_reverse_7eca3 <= 1000.0
# 0.0 <= HMR_0429 <= 1000.0
# 0.0 <= HMR_0429_reverse_1b859 <= 1000.0
# 0.0 <= HMR_0430 <= 1000.0
# 0.0 <= HMR_0430_reverse_8758d <= 0.0
# 0.0 <= HMR_0428 <= 1000.0
# 0.0 <= HMR_0428_reverse_92801 <= 0.0
# 0.0 <= HMR_0431 <= 1000.0
# 0.0 <= HMR_0431_reverse_2dce6 <= 0.0
# 0.0 <= HMR_3002 <= 1000.0
# 0.0 <= HMR_3002_reverse_26b29 <= 1000.0
# 0.0 <= HMR_3740 <= 1000.0
# 0.0 <= HMR_3740_reverse_8eb9a <= 0.0
# 0.0 <= EX_M00008[e] <= 1000.0
# 0.0 <= EX_M00008[e]_reverse_01c95 <= 1000.0
# 0.0 <= HMR_2430 <= 1000.0
# 0.0 <= HMR_2430_reverse_bb647 <= 0.0
# 0.0 <= HMR_2433 <= 1000.0
# 0.0 <= HMR_2433_reverse_30739 <= 0.0
# 0.0 <= HMR_2768 <= 1000.0
# 0.0 <= HMR_2768_reverse_9d967 <= 1000.0
# 0.0 <= HMR_0542 <= 1000.0
# 0.0 <= HMR_0542_reverse_d458c <= 0.0
# 0.0 <= HMR_2770 <= 1000.0
# 0.0 <= HMR_2770_reverse_7faba <= 1000.0
# 0.0 <= HMR_3423 <= 1000.0
# 0.0 <= HMR_3423_reverse_0b304 <= 0.0
# 0.0 <= HMR_2901 <= 1000.0
# 0.0 <= HMR_2901_reverse_a457a <= 1000.0
# 0.0 <= HMR_3681 <= 1000.0
# 0.0 <= HMR_3681_reverse_78c01 <= 0.0
# 0.0 <= RE3164R <= 1000.0
# 0.0 <= RE3164R_reverse_b90bf <= 1000.0
# 0.0 <= HMR_0381 <= 1000.0
# 0.0 <= HMR_0381_reverse_a1262 <= 1000.0
# 0.0 <= HMR_0382 <= 1000.0
# 0.0 <= HMR_0382_reverse_f21ed <= 0.0
# 0.0 <= HMR_0380 <= 1000.0
# 0.0 <= HMR_0380_reverse_b2e7e <= 0.0
# 0.0 <= HMR_0383 <= 1000.0
# 0.0 <= HMR_0383_reverse_a25a1 <= 0.0
# 0.0 <= HMR_2989 <= 1000.0
# 0.0 <= HMR_2989_reverse_50420 <= 1000.0
# 0.0 <= HMR_3728 <= 1000.0
# 0.0 <= HMR_3728_reverse_be4a4 <= 0.0
# 0.0 <= EX_M00010[e] <= 1000.0
# 0.0 <= EX_M00010[e]_reverse_424c9 <= 1000.0
# 0.0 <= HMR_2733 <= 1000.0
# 0.0 <= HMR_2733_reverse_2618a <= 1000.0
# 0.0 <= HMR_2734 <= 1000.0
# 0.0 <= HMR_2734_reverse_6c095 <= 1000.0
# 0.0 <= HMR_2871 <= 1000.0
# 0.0 <= HMR_2871_reverse_0378a <= 1000.0
# 0.0 <= HMR_2735 <= 1000.0
# 0.0 <= HMR_2735_reverse_03429 <= 1000.0
# 0.0 <= HMR_2872 <= 1000.0
# 0.0 <= HMR_2872_reverse_fa52f <= 1000.0
# 0.0 <= HMR_2537 <= 1000.0
# 0.0 <= HMR_2537_reverse_d4191 <= 0.0
# 0.0 <= HMR_2540 <= 1000.0
# 0.0 <= HMR_2540_reverse_1aa4d <= 0.0
# 0.0 <= HMR_0530 <= 1000.0
# 0.0 <= HMR_0530_reverse_12aa2 <= 0.0
# 0.0 <= HMR_3431 <= 1000.0
# 0.0 <= HMR_3431_reverse_0d191 <= 0.0
# 0.0 <= HMR_3669 <= 1000.0
# 0.0 <= HMR_3669_reverse_59cb3 <= 0.0
# 0.0 <= HMR_8546 <= 1000.0
# 0.0 <= HMR_8546_reverse_708d7 <= 1000.0
# 0.0 <= HMR_1304 <= 1000.0
# 0.0 <= HMR_1304_reverse_aec8b <= 0.0
# 0.0 <= HMR_1303 <= 1000.0
# 0.0 <= HMR_1303_reverse_cc346 <= 0.0
# 0.0 <= HMR_0319 <= 1000.0
# 0.0 <= HMR_0319_reverse_48461 <= 1000.0
# 0.0 <= HMR_2321 <= 1000.0
# 0.0 <= HMR_2321_reverse_49e7f <= 0.0
# 0.0 <= HMR_2324 <= 1000.0
# 0.0 <= HMR_2324_reverse_d1883 <= 0.0
# 0.0 <= HMR_0320 <= 1000.0
# 0.0 <= HMR_0320_reverse_bcbb0 <= 0.0
# 0.0 <= HMR_2705 <= 1000.0
# 0.0 <= HMR_2705_reverse_433ed <= 1000.0
# 0.0 <= HMR_0515 <= 1000.0
# 0.0 <= HMR_0515_reverse_2a418 <= 0.0
# 0.0 <= HMR_2707 <= 1000.0
# 0.0 <= HMR_2707_reverse_db7cc <= 1000.0
# 0.0 <= HMR_3218 <= 1000.0
# 0.0 <= HMR_3218_reverse_76a86 <= 0.0
# 0.0 <= HMR_3333 <= 1000.0
# 0.0 <= HMR_3333_reverse_c411e <= 0.0
# 0.0 <= HMR_3334 <= 1000.0
# 0.0 <= HMR_3334_reverse_3b887 <= 0.0
# 0.0 <= HMR_2974 <= 1000.0
# 0.0 <= HMR_2974_reverse_569ba <= 1000.0
# 0.0 <= HMR_2854 <= 1000.0
# 0.0 <= HMR_2854_reverse_fc4c7 <= 1000.0
# 0.0 <= HMR_3654 <= 1000.0
# 0.0 <= HMR_3654_reverse_d405b <= 0.0
# 0.0 <= RE3226R <= 1000.0
# 0.0 <= RE3226R_reverse_cec03 <= 0.0
# 0.0 <= RE3232R <= 1000.0
# 0.0 <= RE3232R_reverse_52731 <= 1000.0
# 0.0 <= HMR_0289 <= 1000.0
# 0.0 <= HMR_0289_reverse_3b819 <= 1000.0
# 0.0 <= HMR_0290 <= 1000.0
# 0.0 <= HMR_0290_reverse_18834 <= 0.0
# 0.0 <= HMR_0288 <= 1000.0
# 0.0 <= HMR_0288_reverse_43c99 <= 0.0
# 0.0 <= HMR_0291 <= 1000.0
# 0.0 <= HMR_0291_reverse_d1ec1 <= 0.0
# 0.0 <= HMR_2968 <= 1000.0
# 0.0 <= HMR_2968_reverse_ac735 <= 1000.0
# 0.0 <= HMR_3706 <= 1000.0
# 0.0 <= HMR_3706_reverse_c8014 <= 0.0
# 0.0 <= EX_M00017[e] <= 1000.0
# 0.0 <= EX_M00017[e]_reverse_5bb1a <= 1000.0
# 0.0 <= HMR_2345 <= 1000.0
# 0.0 <= HMR_2345_reverse_feaf1 <= 0.0
# 0.0 <= HMR_2681 <= 1000.0
# 0.0 <= HMR_2681_reverse_ba225 <= 1000.0
# 0.0 <= HMR_0508 <= 1000.0
# 0.0 <= HMR_0508_reverse_5a31d <= 0.0
# 0.0 <= HMR_3017 <= 1000.0
# 0.0 <= HMR_3017_reverse_bf22a <= 0.0
# 0.0 <= HMR_2683 <= 1000.0
# 0.0 <= HMR_2683_reverse_2e7dd <= 1000.0
# 0.0 <= HMR_3240 <= 1000.0
# 0.0 <= HMR_3240_reverse_52371 <= 0.0
# 0.0 <= HMR_3356 <= 1000.0
# 0.0 <= HMR_3356_reverse_c87d5 <= 0.0
# 0.0 <= HMR_2844 <= 1000.0
# 0.0 <= HMR_2844_reverse_5219a <= 1000.0
# 0.0 <= HMR_3647 <= 1000.0
# 0.0 <= HMR_3647_reverse_5375a <= 0.0
# 0.0 <= HMR_0255 <= 1000.0
# 0.0 <= HMR_0255_reverse_ef464 <= 1000.0
# 0.0 <= HMR_0256 <= 1000.0
# 0.0 <= HMR_0256_reverse_0ff7b <= 0.0
# 0.0 <= HMR_0254 <= 1000.0
# 0.0 <= HMR_0254_reverse_97a97 <= 0.0
# 0.0 <= HMR_0257 <= 1000.0
# 0.0 <= HMR_0257_reverse_345ab <= 0.0
# 0.0 <= HMR_2962 <= 1000.0
# 0.0 <= HMR_2962_reverse_39885 <= 1000.0
# 0.0 <= HMR_3698 <= 1000.0
# 0.0 <= HMR_3698_reverse_57d62 <= 0.0
# 0.0 <= EX_M00019[e] <= 1000.0
# 0.0 <= EX_M00019[e]_reverse_d72f0 <= 1000.0
# 0.0 <= HMR_0271 <= 1000.0
# 0.0 <= HMR_0271_reverse_67978 <= 1000.0
# 0.0 <= HMR_2292 <= 1000.0
# 0.0 <= HMR_2292_reverse_7652f <= 0.0
# 0.0 <= HMR_2657 <= 1000.0
# 0.0 <= HMR_2657_reverse_d4fd7 <= 1000.0
# 0.0 <= HMR_0500 <= 1000.0
# 0.0 <= HMR_0500_reverse_787c0 <= 0.0
# 0.0 <= HMR_2659 <= 1000.0
# 0.0 <= HMR_2659_reverse_7c99b <= 1000.0
# 0.0 <= HMR_3406 <= 1000.0
# 0.0 <= HMR_3406_reverse_21e9d <= 0.0
# 0.0 <= HMR_2822 <= 1000.0
# 0.0 <= HMR_2822_reverse_fc694 <= 1000.0
# 0.0 <= HMR_3639 <= 1000.0
# 0.0 <= HMR_3639_reverse_a51bf <= 0.0
# 0.0 <= HMR_0433 <= 1000.0
# 0.0 <= HMR_0433_reverse_1f685 <= 1000.0
# 0.0 <= HMR_0434 <= 1000.0
# 0.0 <= HMR_0434_reverse_448c1 <= 0.0
# 0.0 <= HMR_0432 <= 1000.0
# 0.0 <= HMR_0432_reverse_2bb2a <= 0.0
# 0.0 <= HMR_0435 <= 1000.0
# 0.0 <= HMR_0435_reverse_31bec <= 0.0
# 0.0 <= HMR_3003 <= 1000.0
# 0.0 <= HMR_3003_reverse_921e1 <= 1000.0
# 0.0 <= HMR_3741 <= 1000.0
# 0.0 <= HMR_3741_reverse_4dbbc <= 0.0
# 0.0 <= EX_M00021[e] <= 1000.0
# 0.0 <= EX_M00021[e]_reverse_ddf2e <= 1000.0
# 0.0 <= HMR_2771 <= 1000.0
# 0.0 <= HMR_2771_reverse_dc684 <= 1000.0
# 0.0 <= HMR_2772 <= 1000.0
# 0.0 <= HMR_2772_reverse_60260 <= 1000.0
# 0.0 <= HMR_2902 <= 1000.0
# 0.0 <= HMR_2902_reverse_2d612 <= 1000.0
# 0.0 <= HMR_2773 <= 1000.0
# 0.0 <= HMR_2773_reverse_7adf5 <= 1000.0
# 0.0 <= HMR_2903 <= 1000.0
# 0.0 <= HMR_2903_reverse_11f4a <= 1000.0
# 0.0 <= HMR_2436 <= 1000.0
# 0.0 <= HMR_2436_reverse_e26df <= 0.0
# 0.0 <= HMR_0543 <= 1000.0
# 0.0 <= HMR_0543_reverse_c576f <= 0.0
# 0.0 <= HMR_3424 <= 1000.0
# 0.0 <= HMR_3424_reverse_1869d <= 0.0
# 0.0 <= HMR_3682 <= 1000.0
# 0.0 <= HMR_3682_reverse_b0ebf <= 0.0
# 0.0 <= HMR_2912 <= 1000.0
# 0.0 <= HMR_2912_reverse_6c766 <= 1000.0
# 0.0 <= HMR_2913 <= 1000.0
# 0.0 <= HMR_2913_reverse_22785 <= 1000.0
# 0.0 <= HMR_2914 <= 1000.0
# 0.0 <= HMR_2914_reverse_b7549 <= 1000.0
# 0.0 <= HMR_0337 <= 1000.0
# 0.0 <= HMR_0337_reverse_f69dc <= 1000.0
# 0.0 <= HMR_2330 <= 1000.0
# 0.0 <= HMR_2330_reverse_93dd0 <= 0.0
# 0.0 <= HMR_2332 <= 1000.0
# 0.0 <= HMR_2332_reverse_6652b <= 0.0
# 0.0 <= HMR_0338 <= 1000.0
# 0.0 <= HMR_0338_reverse_fa222 <= 0.0
# 0.0 <= HMR_0519 <= 1000.0
# 0.0 <= HMR_0519_reverse_83518 <= 0.0
# 0.0 <= HMR_3020 <= 1000.0
# 0.0 <= HMR_3020_reverse_258bd <= 0.0
# 0.0 <= NRVNCCOAtxc <= 1000.0
# 0.0 <= NRVNCCOAtxc_reverse_68246 <= 0.0
# 0.0 <= HMR_3329 <= 1000.0
# 0.0 <= HMR_3329_reverse_4df71 <= 0.0
# 0.0 <= HMR_3330 <= 1000.0
# 0.0 <= HMR_3330_reverse_ea271 <= 0.0
# 0.0 <= FAOXC241181x <= 1000.0
# 0.0 <= FAOXC241181x_reverse_3adf2 <= 0.0
# 0.0 <= FAOXC241C221x <= 1000.0
# 0.0 <= FAOXC241C221x_reverse_1f5d7 <= 0.0
# 0.0 <= HMR_2978 <= 1000.0
# 0.0 <= HMR_2978_reverse_d39a6 <= 1000.0
# 0.0 <= HMR_3658 <= 1000.0
# 0.0 <= HMR_3658_reverse_fbbf3 <= 0.0
# 0.0 <= RE3236R <= 1000.0
# 0.0 <= RE3236R_reverse_5dbca <= 1000.0
# 0.0 <= HMR_1253 <= 1000.0
# 0.0 <= HMR_1253_reverse_daf74 <= 0.0
# 0.0 <= HMR_1255 <= 1000.0
# 0.0 <= HMR_1255_reverse_39842 <= 0.0
# 0.0 <= HMR_1254 <= 1000.0
# 0.0 <= HMR_1254_reverse_73b82 <= 0.0
# 0.0 <= HMR_1256 <= 1000.0
# 0.0 <= HMR_1256_reverse_352ae <= 0.0
# 0.0 <= HMR_1291 <= 1000.0
# 0.0 <= HMR_1291_reverse_d6596 <= 0.0
# 0.0 <= HMR_1292 <= 1000.0
# 0.0 <= HMR_1292_reverse_f29bf <= 0.0
# 0.0 <= HMR_2586 <= 1000.0
# 0.0 <= HMR_2586_reverse_395e8 <= 0.0
# 0.0 <= HMR_2585 <= 1000.0
# 0.0 <= HMR_2585_reverse_50268 <= 0.0
# 0.0 <= CE7090te <= 1000.0
# 0.0 <= CE7090te_reverse_58fb0 <= 0.0
# 0.0 <= HMR_2588 <= 1000.0
# 0.0 <= HMR_2588_reverse_2db8e <= 1000.0
# 0.0 <= HMR_7056 <= 1000.0
# 0.0 <= HMR_7056_reverse_10ce8 <= 0.0
# 0.0 <= HMR_7003 <= 1000.0
# 0.0 <= HMR_7003_reverse_10aa3 <= 0.0
# 0.0 <= HMR_7001 <= 1000.0
# 0.0 <= HMR_7001_reverse_7442b <= 0.0
# 0.0 <= HMR_7004 <= 1000.0
# 0.0 <= HMR_7004_reverse_ba520 <= 0.0
# 0.0 <= HMR_7013 <= 1000.0
# 0.0 <= HMR_7013_reverse_a1da0 <= 0.0
# 0.0 <= HMR_7002 <= 1000.0
# 0.0 <= HMR_7002_reverse_825e4 <= 0.0
# 0.0 <= HMR_7014 <= 1000.0
# 0.0 <= HMR_7014_reverse_aca76 <= 0.0
# 0.0 <= HMR_2139 <= 1000.0
# 0.0 <= HMR_2139_reverse_123b4 <= 0.0
# 0.0 <= HMR_8000 <= 1000.0
# 0.0 <= HMR_8000_reverse_d5c1d <= 0.0
# 0.0 <= HMR_2138 <= 1000.0
# 0.0 <= HMR_2138_reverse_4e591 <= 0.0
# 0.0 <= HMR_8006 <= 1000.0
# 0.0 <= HMR_8006_reverse_7248e <= 0.0
# 0.0 <= HMR_1644 <= 1000.0
# 0.0 <= HMR_1644_reverse_7f8bd <= 0.0
# 0.0 <= HMR_1651 <= 1000.0
# 0.0 <= HMR_1651_reverse_d72de <= 1000.0
# 0.0 <= HMR_1642 <= 1000.0
# 0.0 <= HMR_1642_reverse_412d0 <= 0.0
# 0.0 <= HMR_1646 <= 1000.0
# 0.0 <= HMR_1646_reverse_d2769 <= 0.0
# 0.0 <= HMR_1760 <= 1000.0
# 0.0 <= HMR_1760_reverse_86532 <= 0.0
# 0.0 <= HMR_1706 <= 1000.0
# 0.0 <= HMR_1706_reverse_ed8cb <= 0.0
# 0.0 <= HMR_1708 <= 1000.0
# 0.0 <= HMR_1708_reverse_ff5d2 <= 0.0
# 0.0 <= HMR_1761 <= 1000.0
# 0.0 <= HMR_1761_reverse_98328 <= 0.0
# 0.0 <= ACOX22x <= 1000.0
# 0.0 <= ACOX22x_reverse_23b44 <= 0.0
# 0.0 <= HSD17B42x <= 1000.0
# 0.0 <= HSD17B42x_reverse_126c0 <= 0.0
# 0.0 <= HMR_2166 <= 1000.0
# 0.0 <= HMR_2166_reverse_f0294 <= 0.0
# 0.0 <= HMR_2167 <= 1000.0
# 0.0 <= HMR_2167_reverse_2091f <= 0.0
# 0.0 <= HMR_3142 <= 1000.0
# 0.0 <= HMR_3142_reverse_5b389 <= 0.0
# 0.0 <= HMR_3143 <= 1000.0
# 0.0 <= HMR_3143_reverse_a5dea <= 0.0
# 0.0 <= HMR_3298 <= 1000.0
# 0.0 <= HMR_3298_reverse_c7320 <= 1000.0
# 0.0 <= r0735 <= 1000.0
# 0.0 <= r0735_reverse_a27d8 <= 1000.0
# 0.0 <= r1451 <= 1000.0
# 0.0 <= r1451_reverse_6ff45 <= 0.0
# 0.0 <= FAOXC101C8m <= 1000.0
# 0.0 <= FAOXC101C8m_reverse_2d6d7 <= 0.0
# 0.0 <= HMR_3090 <= 1000.0
# 0.0 <= HMR_3090_reverse_5dcec <= 0.0
# 0.0 <= HMR_3091 <= 1000.0
# 0.0 <= HMR_3091_reverse_5a7a7 <= 0.0
# 0.0 <= HMR_3323 <= 1000.0
# 0.0 <= HMR_3323_reverse_3af10 <= 1000.0
# 0.0 <= FAOXC101C8x <= 1000.0
# 0.0 <= FAOXC101C8x_reverse_a8de3 <= 0.0
# 0.0 <= HMR_2209 <= 1000.0
# 0.0 <= HMR_2209_reverse_fdd2a <= 0.0
# 0.0 <= HMR_2210 <= 1000.0
# 0.0 <= HMR_2210_reverse_e375c <= 0.0
# 0.0 <= HMR_3107 <= 1000.0
# 0.0 <= HMR_3107_reverse_1799c <= 0.0
# 0.0 <= HMR_3108 <= 1000.0
# 0.0 <= HMR_3108_reverse_ffa74 <= 0.0
# 0.0 <= HMR_3066 <= 1000.0
# 0.0 <= HMR_3066_reverse_94f86 <= 0.0
# 0.0 <= HMR_3067 <= 1000.0
# 0.0 <= HMR_3067_reverse_5b548 <= 0.0
# 0.0 <= HMR_2170 <= 1000.0
# 0.0 <= HMR_2170_reverse_d59d7 <= 0.0
# 0.0 <= HMR_2171 <= 1000.0
# 0.0 <= HMR_2171_reverse_c1cc2 <= 0.0
# 0.0 <= HMR_3135 <= 1000.0
# 0.0 <= HMR_3135_reverse_9ff5d <= 0.0
# 0.0 <= HMR_3136 <= 1000.0
# 0.0 <= HMR_3136_reverse_7e6c2 <= 0.0
# 0.0 <= HMR_3272 <= 1000.0
# 0.0 <= HMR_3272_reverse_570f0 <= 1000.0
# 0.0 <= HMR_3239 <= 1000.0
# 0.0 <= HMR_3239_reverse_da8c4 <= 1000.0
# 0.0 <= r0638 <= 1000.0
# 0.0 <= r0638_reverse_22389 <= 1000.0
# 0.0 <= r1447 <= 1000.0
# 0.0 <= r1447_reverse_58e10 <= 0.0
# 0.0 <= HMR_3086 <= 1000.0
# 0.0 <= HMR_3086_reverse_c970f <= 0.0
# 0.0 <= HMR_3087 <= 1000.0
# 0.0 <= HMR_3087_reverse_a4f60 <= 0.0
# 0.0 <= HMR_3355 <= 1000.0
# 0.0 <= HMR_3355_reverse_4508d <= 1000.0
# 0.0 <= HMR_3375 <= 1000.0
# 0.0 <= HMR_3375_reverse_8b6e1 <= 1000.0
# 0.0 <= FAOXC121C10x <= 1000.0
# 0.0 <= FAOXC121C10x_reverse_08009 <= 0.0
# 0.0 <= HMR_2203 <= 1000.0
# 0.0 <= HMR_2203_reverse_38058 <= 0.0
# 0.0 <= HMR_2204 <= 1000.0
# 0.0 <= HMR_2204_reverse_d1ef3 <= 0.0
# 0.0 <= HMR_3111 <= 1000.0
# 0.0 <= HMR_3111_reverse_1d9fb <= 0.0
# 0.0 <= HMR_3112 <= 1000.0
# 0.0 <= HMR_3112_reverse_9822c <= 0.0
# 0.0 <= HMR_3070 <= 1000.0
# 0.0 <= HMR_3070_reverse_96503 <= 0.0
# 0.0 <= HMR_3071 <= 1000.0
# 0.0 <= HMR_3071_reverse_a0288 <= 0.0
# 0.0 <= HMR_2265 <= 1000.0
# 0.0 <= HMR_2265_reverse_ca186 <= 0.0
# 0.0 <= HMR_2266 <= 1000.0
# 0.0 <= HMR_2266_reverse_bf9f6 <= 0.0
# 0.0 <= HMR_3170 <= 1000.0
# 0.0 <= HMR_3170_reverse_dd5b0 <= 0.0
# 0.0 <= HMR_3171 <= 1000.0
# 0.0 <= HMR_3171_reverse_87eb5 <= 0.0
# 0.0 <= HMR_2256 <= 1000.0
# 0.0 <= HMR_2256_reverse_c0ce4 <= 0.0
# 0.0 <= HMR_2257 <= 1000.0
# 0.0 <= HMR_2257_reverse_a123c <= 0.0
# 0.0 <= HMR_3178 <= 1000.0
# 0.0 <= HMR_3178_reverse_18735 <= 0.0
# 0.0 <= HMR_3179 <= 1000.0
# 0.0 <= HMR_3179_reverse_f766d <= 0.0
# 0.0 <= HMR_2234 <= 1000.0
# 0.0 <= HMR_2234_reverse_0b9b8 <= 0.0
# 0.0 <= HMR_2235 <= 1000.0
# 0.0 <= HMR_2235_reverse_36484 <= 0.0
# 0.0 <= HMR_3198 <= 1000.0
# 0.0 <= HMR_3198_reverse_6de59 <= 0.0
# 0.0 <= HMR_3199 <= 1000.0
# 0.0 <= HMR_3199_reverse_30b16 <= 0.0
# 0.0 <= HMR_2218 <= 1000.0
# 0.0 <= HMR_2218_reverse_9f4ab <= 0.0
# 0.0 <= HMR_2219 <= 1000.0
# 0.0 <= HMR_2219_reverse_f165d <= 0.0
# 0.0 <= HMR_3057 <= 1000.0
# 0.0 <= HMR_3057_reverse_bd613 <= 0.0
# 0.0 <= HMR_3058 <= 1000.0
# 0.0 <= HMR_3058_reverse_243c1 <= 0.0
# 0.0 <= HMR_2180 <= 1000.0
# 0.0 <= HMR_2180_reverse_09642 <= 0.0
# 0.0 <= HMR_2181 <= 1000.0
# 0.0 <= HMR_2181_reverse_37571 <= 0.0
# 0.0 <= HMR_3121 <= 1000.0
# 0.0 <= HMR_3121_reverse_edb9f <= 0.0
# 0.0 <= HMR_3122 <= 1000.0
# 0.0 <= HMR_3122_reverse_030b4 <= 0.0
# 0.0 <= C161CPT22 <= 1000.0
# 0.0 <= C161CPT22_reverse_f4fe9 <= 1000.0
# 0.0 <= FAOXC161802m <= 1000.0
# 0.0 <= FAOXC161802m_reverse_19fe5 <= 0.0
# 0.0 <= r0309 <= 1000.0
# 0.0 <= r0309_reverse_6c083 <= 1000.0
# 0.0 <= r0310 <= 1000.0
# 0.0 <= r0310_reverse_ab09a <= 0.0
# 0.0 <= HMR_3078 <= 1000.0
# 0.0 <= HMR_3078_reverse_66ffa <= 0.0
# 0.0 <= HMR_3079 <= 1000.0
# 0.0 <= HMR_3079_reverse_95a86 <= 0.0
# 0.0 <= HMR_2158 <= 1000.0
# 0.0 <= HMR_2158_reverse_2da19 <= 0.0
# 0.0 <= HMR_2159 <= 1000.0
# 0.0 <= HMR_2159_reverse_fff52 <= 0.0
# 0.0 <= HMR_3156 <= 1000.0
# 0.0 <= HMR_3156_reverse_2b4d3 <= 0.0
# 0.0 <= HMR_3157 <= 1000.0
# 0.0 <= HMR_3157_reverse_8860a <= 0.0
# 0.0 <= r0791 <= 1000.0
# 0.0 <= r0791_reverse_b472d <= 1000.0
# 0.0 <= r1450 <= 1000.0
# 0.0 <= r1450_reverse_62e40 <= 0.0
# 0.0 <= FAOXC61C4m <= 1000.0
# 0.0 <= FAOXC61C4m_reverse_921d3 <= 0.0
# 0.0 <= FAOXC61m <= 1000.0
# 0.0 <= FAOXC61m_reverse_ac564 <= 0.0
# 0.0 <= HMR_3098 <= 1000.0
# 0.0 <= HMR_3098_reverse_a1159 <= 0.0
# 0.0 <= HMR_3099 <= 1000.0
# 0.0 <= HMR_3099_reverse_d1737 <= 0.0
# 0.0 <= FAOXC61C4x <= 1000.0
# 0.0 <= FAOXC61C4x_reverse_065ba <= 0.0
# 0.0 <= FAOXC61x <= 1000.0
# 0.0 <= FAOXC61x_reverse_fec9f <= 0.0
# 0.0 <= HMR_2261 <= 1000.0
# 0.0 <= HMR_2261_reverse_a6edf <= 0.0
# 0.0 <= HMR_2262 <= 1000.0
# 0.0 <= HMR_2262_reverse_3bba5 <= 0.0
# 0.0 <= HMR_3174 <= 1000.0
# 0.0 <= HMR_3174_reverse_05ccd <= 0.0
# 0.0 <= HMR_3175 <= 1000.0
# 0.0 <= HMR_3175_reverse_87a72 <= 0.0
# 0.0 <= HMR_2238 <= 1000.0
# 0.0 <= HMR_2238_reverse_6d737 <= 0.0
# 0.0 <= HMR_2239 <= 1000.0
# 0.0 <= HMR_2239_reverse_3c1cd <= 0.0
# 0.0 <= HMR_3194 <= 1000.0
# 0.0 <= HMR_3194_reverse_904f4 <= 0.0
# 0.0 <= HMR_3195 <= 1000.0
# 0.0 <= HMR_3195_reverse_ece1a <= 0.0
# 0.0 <= HMR_2193 <= 1000.0
# 0.0 <= HMR_2193_reverse_e8359 <= 0.0
# 0.0 <= HMR_2194 <= 1000.0
# 0.0 <= HMR_2194_reverse_1bb50 <= 0.0
# 0.0 <= DESAT18_5 <= 1000.0
# 0.0 <= DESAT18_5_reverse_a4785 <= 0.0
# 0.0 <= DESAT18_8 <= 1000.0
# 0.0 <= DESAT18_8_reverse_86bd8 <= 0.0
# 0.0 <= ELAIDCPT1 <= 1000.0
# 0.0 <= ELAIDCPT1_reverse_44fad <= 1000.0
# 0.0 <= FACOAL1813 <= 1000.0
# 0.0 <= FACOAL1813_reverse_03467 <= 1000.0
# 0.0 <= HMR_3115 <= 1000.0
# 0.0 <= HMR_3115_reverse_881d3 <= 0.0
# 0.0 <= HMR_3116 <= 1000.0
# 0.0 <= HMR_3116_reverse_71e93 <= 0.0
# 0.0 <= ELAIDCPT2 <= 1000.0
# 0.0 <= ELAIDCPT2_reverse_b29e6 <= 1000.0
# 0.0 <= FAOXC1811601m <= 1000.0
# 0.0 <= FAOXC1811601m_reverse_6b239 <= 0.0
# 0.0 <= HMR_3074 <= 1000.0
# 0.0 <= HMR_3074_reverse_183cd <= 0.0
# 0.0 <= HMR_3075 <= 1000.0
# 0.0 <= HMR_3075_reverse_8995c <= 0.0
# 0.0 <= HMR_2162 <= 1000.0
# 0.0 <= HMR_2162_reverse_f53a3 <= 0.0
# 0.0 <= HMR_2163 <= 1000.0
# 0.0 <= HMR_2163_reverse_da37c <= 0.0
# 0.0 <= HMR_3149 <= 1000.0
# 0.0 <= HMR_3149_reverse_32c35 <= 0.0
# 0.0 <= HMR_3150 <= 1000.0
# 0.0 <= HMR_3150_reverse_4f67a <= 0.0
# 0.0 <= r0633 <= 1000.0
# 0.0 <= r0633_reverse_b0e60 <= 1000.0
# 0.0 <= r1448 <= 1000.0
# 0.0 <= r1448_reverse_81a75 <= 0.0
# 0.0 <= HMR_3094 <= 1000.0
# 0.0 <= HMR_3094_reverse_373d8 <= 0.0
# 0.0 <= HMR_3095 <= 1000.0
# 0.0 <= HMR_3095_reverse_3d496 <= 0.0
# 0.0 <= HMR_2251 <= 1000.0
# 0.0 <= HMR_2251_reverse_6baaf <= 0.0
# 0.0 <= HMR_2252 <= 1000.0
# 0.0 <= HMR_2252_reverse_86462 <= 0.0
# 0.0 <= HMR_3182 <= 1000.0
# 0.0 <= HMR_3182_reverse_aac6a <= 0.0
# 0.0 <= HMR_3183 <= 1000.0
# 0.0 <= HMR_3183_reverse_d0b58 <= 0.0
# 0.0 <= HMR_2230 <= 1000.0
# 0.0 <= HMR_2230_reverse_d388f <= 0.0
# 0.0 <= HMR_2231 <= 1000.0
# 0.0 <= HMR_2231_reverse_e30f2 <= 0.0
# 0.0 <= HMR_3202 <= 1000.0
# 0.0 <= HMR_3202_reverse_d1703 <= 0.0
# 0.0 <= HMR_3203 <= 1000.0
# 0.0 <= HMR_3203_reverse_54433 <= 0.0
# 0.0 <= HMR_2213 <= 1000.0
# 0.0 <= HMR_2213_reverse_345a5 <= 0.0
# 0.0 <= HMR_2214 <= 1000.0
# 0.0 <= HMR_2214_reverse_e4781 <= 0.0
# 0.0 <= HMR_3062 <= 1000.0
# 0.0 <= HMR_3062_reverse_b9ea0 <= 0.0
# 0.0 <= HMR_3063 <= 1000.0
# 0.0 <= HMR_3063_reverse_da506 <= 0.0
# 0.0 <= HMR_2175 <= 1000.0
# 0.0 <= HMR_2175_reverse_6e785 <= 0.0
# 0.0 <= HMR_2176 <= 1000.0
# 0.0 <= HMR_2176_reverse_928ac <= 0.0
# 0.0 <= HMR_3128 <= 1000.0
# 0.0 <= HMR_3128_reverse_54ff9 <= 0.0
# 0.0 <= HMR_3129 <= 1000.0
# 0.0 <= HMR_3129_reverse_229c8 <= 0.0
# 0.0 <= r0652 <= 1000.0
# 0.0 <= r0652_reverse_efc98 <= 1000.0
# 0.0 <= r1449 <= 1000.0
# 0.0 <= r1449_reverse_eec96 <= 0.0
# 0.0 <= HMR_3082 <= 1000.0
# 0.0 <= HMR_3082_reverse_be5f7 <= 0.0
# 0.0 <= HMR_3083 <= 1000.0
# 0.0 <= HMR_3083_reverse_45238 <= 0.0
# 0.0 <= HMR_2269 <= 1000.0
# 0.0 <= HMR_2269_reverse_86ccc <= 0.0
# 0.0 <= HMR_2270 <= 1000.0
# 0.0 <= HMR_2270_reverse_d3732 <= 0.0
# 0.0 <= HMR_2246 <= 1000.0
# 0.0 <= HMR_2246_reverse_274a5 <= 0.0
# 0.0 <= HMR_2247 <= 1000.0
# 0.0 <= HMR_2247_reverse_2565e <= 0.0
# 0.0 <= HMR_3186 <= 1000.0
# 0.0 <= HMR_3186_reverse_22bf3 <= 0.0
# 0.0 <= HMR_3187 <= 1000.0
# 0.0 <= HMR_3187_reverse_b60fd <= 0.0
# 0.0 <= HMR_2242 <= 1000.0
# 0.0 <= HMR_2242_reverse_ca53e <= 0.0
# 0.0 <= HMR_2243 <= 1000.0
# 0.0 <= HMR_2243_reverse_fbc28 <= 0.0
# 0.0 <= HMR_3190 <= 1000.0
# 0.0 <= HMR_3190_reverse_6a09e <= 0.0
# 0.0 <= HMR_3191 <= 1000.0
# 0.0 <= HMR_3191_reverse_3ca1d <= 0.0
# 0.0 <= HMR_3456 <= 1000.0
# 0.0 <= HMR_3456_reverse_8046e <= 0.0
# 0.0 <= HMR_3457 <= 1000.0
# 0.0 <= HMR_3457_reverse_96217 <= 1000.0
# 0.0 <= HMR_3452 <= 1000.0
# 0.0 <= HMR_3452_reverse_203d8 <= 0.0
# 0.0 <= HMR_3453 <= 1000.0
# 0.0 <= HMR_3453_reverse_57bcf <= 0.0
# 0.0 <= HMR_2389 <= 1000.0
# 0.0 <= HMR_2389_reverse_13230 <= 0.0
# 0.0 <= HMR_3491 <= 1000.0
# 0.0 <= HMR_3491_reverse_11321 <= 1000.0
# 0.0 <= HMR_3493 <= 1000.0
# 0.0 <= HMR_3493_reverse_c7eb8 <= 1000.0
# 0.0 <= HMR_3510 <= 1000.0
# 0.0 <= HMR_3510_reverse_c593a <= 0.0
# 0.0 <= HMR_3511 <= 1000.0
# 0.0 <= HMR_3511_reverse_f631e <= 0.0
# 0.0 <= HMR_3488 <= 1000.0
# 0.0 <= HMR_3488_reverse_9c54d <= 0.0
# 0.0 <= HMR_3489 <= 1000.0
# 0.0 <= HMR_3489_reverse_c31e4 <= 1000.0
# 0.0 <= HMR_3498 <= 1000.0
# 0.0 <= HMR_3498_reverse_bbcbb <= 0.0
# 0.0 <= RE3074X <= 1000.0
# 0.0 <= RE3074X_reverse_85508 <= 1000.0
# 0.0 <= HMR_3512 <= 1000.0
# 0.0 <= HMR_3512_reverse_68ec0 <= 0.0
# 0.0 <= HMR_3513 <= 1000.0
# 0.0 <= HMR_3513_reverse_ffb2d <= 0.0
# 0.0 <= HMR_3281 <= 1000.0
# 0.0 <= HMR_3281_reverse_33647 <= 0.0
# 0.0 <= HMR_3282 <= 1000.0
# 0.0 <= HMR_3282_reverse_96c8d <= 0.0
# 0.0 <= HMR_3307 <= 1000.0
# 0.0 <= HMR_3307_reverse_a14ae <= 0.0
# 0.0 <= HMR_3309 <= 1000.0
# 0.0 <= HMR_3309_reverse_38854 <= 0.0
# 0.0 <= HMR_3290 <= 1000.0
# 0.0 <= HMR_3290_reverse_98f21 <= 0.0
# 0.0 <= HMR_3292 <= 1000.0
# 0.0 <= HMR_3292_reverse_d910a <= 0.0
# 0.0 <= HMR_3317 <= 1000.0
# 0.0 <= HMR_3317_reverse_92ebc <= 0.0
# 0.0 <= HMR_3319 <= 1000.0
# 0.0 <= HMR_3319_reverse_e50c6 <= 0.0
# 0.0 <= HMR_3277 <= 1000.0
# 0.0 <= HMR_3277_reverse_72197 <= 0.0
# 0.0 <= HMR_3278 <= 1000.0
# 0.0 <= HMR_3278_reverse_2312a <= 0.0
# 0.0 <= HMR_3302 <= 1000.0
# 0.0 <= HMR_3302_reverse_3fc82 <= 0.0
# 0.0 <= HMR_3304 <= 1000.0
# 0.0 <= HMR_3304_reverse_9f32c <= 0.0
# 0.0 <= HMR_2434 <= 1000.0
# 0.0 <= HMR_2434_reverse_29952 <= 0.0
# 0.0 <= HMR_2435 <= 1000.0
# 0.0 <= HMR_2435_reverse_52a37 <= 0.0
# 0.0 <= HMR_2533 <= 1000.0
# 0.0 <= HMR_2533_reverse_26731 <= 0.0
# 0.0 <= HMR_2535 <= 1000.0
# 0.0 <= HMR_2535_reverse_b3401 <= 0.0
# 0.0 <= HMR_2426 <= 1000.0
# 0.0 <= HMR_2426_reverse_e0f6b <= 0.0
# 0.0 <= HMR_2428 <= 1000.0
# 0.0 <= HMR_2428_reverse_35fee <= 0.0
# 0.0 <= HMR_3237 <= 1000.0
# 0.0 <= HMR_3237_reverse_dcd12 <= 0.0
# 0.0 <= FAOXC141C121x <= 1000.0
# 0.0 <= FAOXC141C121x_reverse_f7810 <= 0.0
# 0.0 <= HMR_3458 <= 1000.0
# 0.0 <= HMR_3458_reverse_fb2f0 <= 0.0
# 0.0 <= HMR_3506 <= 1000.0
# 0.0 <= HMR_3506_reverse_5ee18 <= 0.0
# 0.0 <= HMR_3508 <= 1000.0
# 0.0 <= HMR_3508_reverse_1b7fa <= 0.0
# 0.0 <= HMR_3455 <= 1000.0
# 0.0 <= HMR_3455_reverse_64bc2 <= 1000.0
# 0.0 <= HMR_2762 <= 1000.0
# 0.0 <= HMR_2762_reverse_16927 <= 1000.0
# 0.0 <= HMR_2764 <= 1000.0
# 0.0 <= HMR_2764_reverse_5ebe5 <= 1000.0
# 0.0 <= HMR_2898 <= 1000.0
# 0.0 <= HMR_2898_reverse_a6680 <= 1000.0
# 0.0 <= DCSPTN1CRNt <= 1000.0
# 0.0 <= DCSPTN1CRNt_reverse_72673 <= 1000.0
# 0.0 <= HMR_2766 <= 1000.0
# 0.0 <= HMR_2766_reverse_b0a62 <= 1000.0
# 0.0 <= HMR_2899 <= 1000.0
# 0.0 <= HMR_2899_reverse_5b8be <= 1000.0
# 0.0 <= HMR_0425 <= 1000.0
# 0.0 <= HMR_0425_reverse_99351 <= 1000.0
# 0.0 <= HMR_0426 <= 1000.0
# 0.0 <= HMR_0426_reverse_ea1e5 <= 0.0
# 0.0 <= HMR_0541 <= 1000.0
# 0.0 <= HMR_0541_reverse_55f0f <= 0.0
# 0.0 <= DCSPTN1COAtxc <= 1000.0
# 0.0 <= DCSPTN1COAtxc_reverse_12882 <= 0.0
# 0.0 <= HMR_2412 <= 1000.0
# 0.0 <= HMR_2412_reverse_94998 <= 1000.0
# 0.0 <= HMR_3422 <= 1000.0
# 0.0 <= HMR_3422_reverse_d7e17 <= 0.0
# 0.0 <= FAOXC2252053m <= 1000.0
# 0.0 <= FAOXC2252053m_reverse_ad057 <= 0.0
# 0.0 <= FAOXC225C226m <= 1000.0
# 0.0 <= FAOXC225C226m_reverse_49a9f <= 0.0
# 0.0 <= FAOXC2252053x <= 1000.0
# 0.0 <= FAOXC2252053x_reverse_06deb <= 0.0
# 0.0 <= FAOXC2452256x <= 1000.0
# 0.0 <= FAOXC2452256x_reverse_0ba56 <= 0.0
# 0.0 <= FAOXC225C226x <= 1000.0
# 0.0 <= FAOXC225C226x_reverse_21537 <= 0.0
# 0.0 <= HMR_3001 <= 1000.0
# 0.0 <= HMR_3001_reverse_71372 <= 1000.0
# 0.0 <= HMR_3680 <= 1000.0
# 0.0 <= HMR_3680_reverse_2d192 <= 0.0
# 0.0 <= HMR_0424 <= 1000.0
# 0.0 <= HMR_0424_reverse_0f01f <= 0.0
# 0.0 <= HMR_0427 <= 1000.0
# 0.0 <= HMR_0427_reverse_96963 <= 0.0
# 0.0 <= HMR_9744 <= 1000.0
# 0.0 <= HMR_9744_reverse_39e61 <= 0.0
# 0.0 <= HMR_3593 <= 1000.0
# 0.0 <= HMR_3593_reverse_7243b <= 0.0
# 0.0 <= HMR_3739 <= 1000.0
# 0.0 <= HMR_3739_reverse_53b7b <= 0.0
# 0.0 <= EX_dcsptn1[e] <= 1000.0
# 0.0 <= EX_dcsptn1[e]_reverse_88f91 <= 1000.0
# 0.0 <= HMR_0377 <= 1000.0
# 0.0 <= HMR_0377_reverse_41584 <= 1000.0
# 0.0 <= HMR_0378 <= 1000.0
# 0.0 <= HMR_0378_reverse_5e3cd <= 0.0
# 0.0 <= HMR_2730 <= 1000.0
# 0.0 <= HMR_2730_reverse_93fd6 <= 1000.0
# 0.0 <= HMR_0529 <= 1000.0
# 0.0 <= HMR_0529_reverse_d23b9 <= 0.0
# 0.0 <= HMR_2732 <= 1000.0
# 0.0 <= HMR_2732_reverse_14e46 <= 1000.0
# 0.0 <= HMR_3430 <= 1000.0
# 0.0 <= HMR_3430_reverse_f8013 <= 0.0
# 0.0 <= FAOXC226205m <= 1000.0
# 0.0 <= FAOXC226205m_reverse_da3ed <= 0.0
# 0.0 <= FAOXC226C227m <= 1000.0
# 0.0 <= FAOXC226C227m_reverse_4a67e <= 0.0
# 0.0 <= FAOXC226205x <= 1000.0
# 0.0 <= FAOXC226205x_reverse_4e5f5 <= 0.0
# 0.0 <= FAOXC246226x <= 1000.0
# 0.0 <= FAOXC246226x_reverse_2cb0a <= 0.0
# 0.0 <= HMR_2988 <= 1000.0
# 0.0 <= HMR_2988_reverse_3acf7 <= 1000.0
# 0.0 <= HMR_2870 <= 1000.0
# 0.0 <= HMR_2870_reverse_21b99 <= 1000.0
# 0.0 <= HMR_3668 <= 1000.0
# 0.0 <= HMR_3668_reverse_a6de0 <= 0.0
# 0.0 <= RE3147R <= 1000.0
# 0.0 <= RE3147R_reverse_b0740 <= 1000.0
# 0.0 <= HMR_8769 <= 1000.0
# 0.0 <= HMR_8769_reverse_4587b <= 0.0
# 0.0 <= HMR_8770 <= 1000.0
# 0.0 <= HMR_8770_reverse_d2bd5 <= 0.0
# 0.0 <= HMR_9338 <= 1000.0
# 0.0 <= HMR_9338_reverse_8940a <= 1000.0
# 0.0 <= HMR_0998 <= 1000.0
# 0.0 <= HMR_0998_reverse_65c74 <= 0.0
# 0.0 <= HMR_1002 <= 1000.0
# 0.0 <= HMR_1002_reverse_48bad <= 1000.0
# 0.0 <= HMR_1006 <= 1000.0
# 0.0 <= HMR_1006_reverse_e265f <= 1000.0
# 0.0 <= HMR_0999 <= 1000.0
# 0.0 <= HMR_0999_reverse_cfb44 <= 0.0
# 0.0 <= HMR_1003 <= 1000.0
# 0.0 <= HMR_1003_reverse_00fe2 <= 1000.0
# 0.0 <= HMR_1007 <= 1000.0
# 0.0 <= HMR_1007_reverse_f3c8c <= 1000.0
# 0.0 <= HMR_1000 <= 1000.0
# 0.0 <= HMR_1000_reverse_70109 <= 0.0
# 0.0 <= HMR_1004 <= 1000.0
# 0.0 <= HMR_1004_reverse_97d01 <= 1000.0
# 0.0 <= HMR_1008 <= 1000.0
# 0.0 <= HMR_1008_reverse_9c82c <= 1000.0
# 0.0 <= HMR_3264 <= 1000.0
# 0.0 <= HMR_3264_reverse_65ce6 <= 0.0
# 0.0 <= HMR_2693 <= 1000.0
# 0.0 <= HMR_2693_reverse_5fdcf <= 1000.0
# 0.0 <= HMR_2695 <= 1000.0
# 0.0 <= HMR_2695_reverse_68ffb <= 1000.0
# 0.0 <= HMR_2847 <= 1000.0
# 0.0 <= HMR_2847_reverse_f6a6a <= 1000.0
# 0.0 <= HMR_2697 <= 1000.0
# 0.0 <= HMR_2697_reverse_68d5d <= 1000.0
# 0.0 <= HMR_2848 <= 1000.0
# 0.0 <= HMR_2848_reverse_7e9e0 <= 1000.0
# 0.0 <= HMR_0305 <= 1000.0
# 0.0 <= HMR_0305_reverse_dc98c <= 1000.0
# 0.0 <= HMR_2365 <= 1000.0
# 0.0 <= HMR_2365_reverse_0228e <= 0.0
# 0.0 <= HMR_0306 <= 1000.0
# 0.0 <= HMR_0306_reverse_4bd7f <= 0.0
# 0.0 <= HMR_0512 <= 1000.0
# 0.0 <= HMR_0512_reverse_7e1f5 <= 0.0
# 0.0 <= HMR_3414 <= 1000.0
# 0.0 <= HMR_3414_reverse_87299 <= 0.0
# 0.0 <= HMR_2971 <= 1000.0
# 0.0 <= HMR_2971_reverse_3cfcd <= 1000.0
# 0.0 <= HMR_3651 <= 1000.0
# 0.0 <= HMR_3651_reverse_cd68e <= 0.0
# 0.0 <= HMR_2720 <= 1000.0
# 0.0 <= HMR_2720_reverse_5b0da <= 1000.0
# 0.0 <= HMR_2722 <= 1000.0
# 0.0 <= HMR_2722_reverse_d28b0 <= 1000.0
# 0.0 <= HMR_2865 <= 1000.0
# 0.0 <= HMR_2865_reverse_f09ae <= 1000.0
# 0.0 <= TMNDNCCRNt <= 1000.0
# 0.0 <= TMNDNCCRNt_reverse_ee880 <= 1000.0
# 0.0 <= HMR_2724 <= 1000.0
# 0.0 <= HMR_2724_reverse_fb7b8 <= 1000.0
# 0.0 <= HMR_2866 <= 1000.0
# 0.0 <= HMR_2866_reverse_4d12b <= 1000.0
# 0.0 <= HMR_0361 <= 1000.0
# 0.0 <= HMR_0361_reverse_e2838 <= 1000.0
# 0.0 <= HMR_2484 <= 1000.0
# 0.0 <= HMR_2484_reverse_d71c9 <= 0.0
# 0.0 <= HMR_2486 <= 1000.0
# 0.0 <= HMR_2486_reverse_c8ccb <= 0.0
# 0.0 <= HMR_0362 <= 1000.0
# 0.0 <= HMR_0362_reverse_a1ed1 <= 0.0
# 0.0 <= HMR_0525 <= 1000.0
# 0.0 <= HMR_0525_reverse_7e0d3 <= 0.0
# 0.0 <= DESAT20_2 <= 1000.0
# 0.0 <= DESAT20_2_reverse_6a745 <= 0.0
# 0.0 <= FAEL205 <= 1000.0
# 0.0 <= FAEL205_reverse_d0256 <= 0.0
# 0.0 <= HMR_3428 <= 1000.0
# 0.0 <= HMR_3428_reverse_68f35 <= 0.0
# 0.0 <= FAOXC2051843m <= 1000.0
# 0.0 <= FAOXC2051843m_reverse_d0334 <= 0.0
# 0.0 <= HMR_2984 <= 1000.0
# 0.0 <= HMR_2984_reverse_4aade <= 1000.0
# 0.0 <= HMR_3664 <= 1000.0
# 0.0 <= HMR_3664_reverse_6914d <= 0.0
# 0.0 <= RE3120R <= 1000.0
# 0.0 <= RE3120R_reverse_d017c <= 0.0
# 0.0 <= HMR_0275 <= 1000.0
# 0.0 <= HMR_0275_reverse_836b1 <= 1000.0
# 0.0 <= HMR_0276 <= 1000.0
# 0.0 <= HMR_0276_reverse_ecb4e <= 0.0
# 0.0 <= HMR_0274 <= 1000.0
# 0.0 <= HMR_0274_reverse_9eeff <= 0.0
# 0.0 <= HMR_0277 <= 1000.0
# 0.0 <= HMR_0277_reverse_00ab2 <= 0.0
# 0.0 <= HMR_2964 <= 1000.0
# 0.0 <= HMR_2964_reverse_a56b3 <= 1000.0
# 0.0 <= HMR_3703 <= 1000.0
# 0.0 <= HMR_3703_reverse_071a8 <= 0.0
# 0.0 <= EX_lneldc[e] <= 1000.0
# 0.0 <= EX_lneldc[e]_reverse_560f0 <= 1000.0
# 0.0 <= HMR_2672 <= 1000.0
# 0.0 <= HMR_2672_reverse_5c5a3 <= 1000.0
# 0.0 <= HMR_2673 <= 1000.0
# 0.0 <= HMR_2673_reverse_decfb <= 1000.0
# 0.0 <= HMR_2833 <= 1000.0
# 0.0 <= HMR_2833_reverse_93715 <= 0.0
# 0.0 <= LNELDCCRNt <= 1000.0
# 0.0 <= LNELDCCRNt_reverse_983c6 <= 1000.0
# 0.0 <= LNELDCCRNte <= 1000.0
# 0.0 <= LNELDCCRNte_reverse_00f0b <= 0.0
# 0.0 <= HMR_2674 <= 1000.0
# 0.0 <= HMR_2674_reverse_a8d2e <= 1000.0
# 0.0 <= HMR_2834 <= 1000.0
# 0.0 <= HMR_2834_reverse_b20d7 <= 0.0
# 0.0 <= HMR_2361 <= 1000.0
# 0.0 <= HMR_2361_reverse_b7b4f <= 0.0
# 0.0 <= HMR_2359 <= 1000.0
# 0.0 <= HMR_2359_reverse_40c0b <= 0.0
# 0.0 <= HMR_0505 <= 1000.0
# 0.0 <= HMR_0505_reverse_3a290 <= 0.0
# 0.0 <= DESAT18_6 <= 1000.0
# 0.0 <= DESAT18_6_reverse_32e8a <= 0.0
# 0.0 <= DESAT18_7 <= 1000.0
# 0.0 <= DESAT18_7_reverse_18806 <= 0.0
# 0.0 <= HMR_3409 <= 1000.0
# 0.0 <= HMR_3409_reverse_de0f8 <= 0.0
# 0.0 <= FAOXC18280m <= 1000.0
# 0.0 <= FAOXC18280m_reverse_70e65 <= 0.0
# 0.0 <= FAOXTC182TC162m <= 1000.0
# 0.0 <= FAOXTC182TC162m_reverse_bab15 <= 0.0
# 0.0 <= HMR_3644 <= 1000.0
# 0.0 <= HMR_3644_reverse_50dae <= 0.0
# 0.0 <= HMR_2714 <= 1000.0
# 0.0 <= HMR_2714_reverse_648ba <= 1000.0
# 0.0 <= HMR_2715 <= 1000.0
# 0.0 <= HMR_2715_reverse_1bc04 <= 1000.0
# 0.0 <= HMR_2861 <= 1000.0
# 0.0 <= HMR_2861_reverse_5deec <= 1000.0
# 0.0 <= STRDNCCRNt <= 1000.0
# 0.0 <= STRDNCCRNt_reverse_fd4df <= 1000.0
# 0.0 <= HMR_2716 <= 1000.0
# 0.0 <= HMR_2716_reverse_884ce <= 1000.0
# 0.0 <= HMR_2862 <= 1000.0
# 0.0 <= HMR_2862_reverse_3f959 <= 1000.0
# 0.0 <= HMR_0353 <= 1000.0
# 0.0 <= HMR_0353_reverse_261a6 <= 1000.0
# 0.0 <= HMR_2472 <= 1000.0
# 0.0 <= HMR_2472_reverse_65dc4 <= 0.0
# 0.0 <= HMR_2475 <= 1000.0
# 0.0 <= HMR_2475_reverse_c53d6 <= 0.0
# 0.0 <= HMR_0354 <= 1000.0
# 0.0 <= HMR_0354_reverse_5d7a6 <= 0.0
# 0.0 <= HMR_0523 <= 1000.0
# 0.0 <= HMR_0523_reverse_d342e <= 0.0
# 0.0 <= DESAT18_10 <= 1000.0
# 0.0 <= DESAT18_10_reverse_cac11 <= 0.0
# 0.0 <= FAEL184 <= 1000.0
# 0.0 <= FAEL184_reverse_a691d <= 0.0
# 0.0 <= STRDNCCOAtxc <= 1000.0
# 0.0 <= STRDNCCOAtxc_reverse_14b27 <= 0.0
# 0.0 <= HMR_9719 <= 1000.0
# 0.0 <= HMR_9719_reverse_f55c7 <= 0.0
# 0.0 <= FAOXC18480m <= 1000.0
# 0.0 <= FAOXC18480m_reverse_9f161 <= 0.0
# 0.0 <= FAOXC204184m <= 1000.0
# 0.0 <= FAOXC204184m_reverse_4e908 <= 0.0
# 0.0 <= FAOXC184C164m <= 1000.0
# 0.0 <= FAOXC184C164m_reverse_f34f5 <= 0.0
# 0.0 <= HMR_2982 <= 1000.0
# 0.0 <= HMR_2982_reverse_2af69 <= 1000.0
# 0.0 <= HMR_3662 <= 1000.0
# 0.0 <= HMR_3662_reverse_cdc7a <= 0.0
# 0.0 <= RE3110R <= 1000.0
# 0.0 <= RE3110R_reverse_31a94 <= 0.0
# 0.0 <= HMR_2927 <= 1000.0
# 0.0 <= HMR_2927_reverse_d6293 <= 1000.0
# 0.0 <= HMR_2928 <= 1000.0
# 0.0 <= HMR_2928_reverse_c96e7 <= 1000.0
# 0.0 <= TETPENT6CRNt <= 1000.0
# 0.0 <= TETPENT6CRNt_reverse_acf5e <= 1000.0
# 0.0 <= HMR_2929 <= 1000.0
# 0.0 <= HMR_2929_reverse_f4c55 <= 1000.0
# 0.0 <= HMR_0421 <= 1000.0
# 0.0 <= HMR_0421_reverse_b8419 <= 1000.0
# 0.0 <= HMR_2403 <= 1000.0
# 0.0 <= HMR_2403_reverse_00f9d <= 0.0
# 0.0 <= HMR_0422 <= 1000.0
# 0.0 <= HMR_0422_reverse_3f0e6 <= 0.0
# 0.0 <= HMR_0540 <= 1000.0
# 0.0 <= HMR_0540_reverse_3fed5 <= 0.0
# 0.0 <= HMR_2407 <= 1000.0
# 0.0 <= HMR_2407_reverse_8dc2b <= 1000.0
# 0.0 <= HMR_2408 <= 1000.0
# 0.0 <= HMR_2408_reverse_189dd <= 0.0
# 0.0 <= HMR_3000 <= 1000.0
# 0.0 <= HMR_3000_reverse_7e522 <= 1000.0
# 0.0 <= HMR_3679 <= 1000.0
# 0.0 <= HMR_3679_reverse_ac331 <= 0.0
# 0.0 <= HMR_0420 <= 1000.0
# 0.0 <= HMR_0420_reverse_7f97d <= 0.0
# 0.0 <= HMR_0423 <= 1000.0
# 0.0 <= HMR_0423_reverse_b3da1 <= 0.0
# 0.0 <= HMR_3738 <= 1000.0
# 0.0 <= HMR_3738_reverse_28fec <= 0.0
# 0.0 <= EX_tetpent6[e] <= 1000.0
# 0.0 <= EX_tetpent6[e]_reverse_852cc <= 1000.0
# 0.0 <= HMR_2930 <= 1000.0
# 0.0 <= HMR_2930_reverse_ed398 <= 1000.0
# 0.0 <= HMR_2931 <= 1000.0
# 0.0 <= HMR_2931_reverse_58f39 <= 1000.0
# 0.0 <= HMR_2932 <= 1000.0
# 0.0 <= HMR_2932_reverse_6d791 <= 1000.0
# 0.0 <= HMR_0373 <= 1000.0
# 0.0 <= HMR_0373_reverse_978c8 <= 1000.0
# 0.0 <= HMR_2505 <= 1000.0
# 0.0 <= HMR_2505_reverse_34632 <= 0.0
# 0.0 <= HMR_0374 <= 1000.0
# 0.0 <= HMR_0374_reverse_2f841 <= 0.0
# 0.0 <= HMR_0528 <= 1000.0
# 0.0 <= HMR_0528_reverse_41cd2 <= 0.0
# 0.0 <= HMR_2509 <= 1000.0
# 0.0 <= HMR_2509_reverse_4d18c <= 1000.0
# 0.0 <= HMR_2510 <= 1000.0
# 0.0 <= HMR_2510_reverse_40758 <= 0.0
# 0.0 <= HMR_2987 <= 1000.0
# 0.0 <= HMR_2987_reverse_154fe <= 1000.0
# 0.0 <= HMR_3667 <= 1000.0
# 0.0 <= HMR_3667_reverse_dca82 <= 0.0
# 0.0 <= HMR_0372 <= 1000.0
# 0.0 <= HMR_0372_reverse_c49ea <= 0.0
# 0.0 <= HMR_0375 <= 1000.0
# 0.0 <= HMR_0375_reverse_54204 <= 0.0
# 0.0 <= HMR_3726 <= 1000.0
# 0.0 <= HMR_3726_reverse_d9c07 <= 0.0
# 0.0 <= EX_tethex3[e] <= 1000.0
# 0.0 <= EX_tethex3[e]_reverse_d7e1f <= 1000.0
# 0.0 <= HMR_0272 <= 1000.0
# 0.0 <= HMR_0272_reverse_26599 <= 0.0
# 0.0 <= HMR_0270 <= 1000.0
# 0.0 <= HMR_0270_reverse_c9908 <= 0.0
# 0.0 <= HMR_0273 <= 1000.0
# 0.0 <= HMR_0273_reverse_30570 <= 0.0
# 0.0 <= EX_M00115[e] <= 1000.0
# 0.0 <= EX_M00115[e]_reverse_ef0e6 <= 1000.0
# 0.0 <= HMR_2347 <= 1000.0
# 0.0 <= HMR_2347_reverse_ccccf <= 0.0
# 0.0 <= HMR_2296 <= 1000.0
# 0.0 <= HMR_2296_reverse_9cce8 <= 0.0
# 0.0 <= HMR_2669 <= 1000.0
# 0.0 <= HMR_2669_reverse_29b04 <= 1000.0
# 0.0 <= HMR_0504 <= 1000.0
# 0.0 <= HMR_0504_reverse_32b4d <= 0.0
# 0.0 <= HMR_2671 <= 1000.0
# 0.0 <= HMR_2671_reverse_e908c <= 1000.0
# 0.0 <= HMR_3408 <= 1000.0
# 0.0 <= HMR_3408_reverse_d5111 <= 0.0
# 0.0 <= HMR_2832 <= 1000.0
# 0.0 <= HMR_2832_reverse_7385a <= 1000.0
# 0.0 <= HMR_3643 <= 1000.0
# 0.0 <= HMR_3643_reverse_43757 <= 0.0
# 0.0 <= HMR_0204 <= 1000.0
# 0.0 <= HMR_0204_reverse_d7dbf <= 1000.0
# 0.0 <= HMR_0206 <= 1000.0
# 0.0 <= HMR_0206_reverse_f6c1d <= 0.0
# 0.0 <= HMR_0203 <= 1000.0
# 0.0 <= HMR_0203_reverse_ee0e0 <= 0.0
# 0.0 <= HMR_0207 <= 1000.0
# 0.0 <= HMR_0207_reverse_1c094 <= 0.0
# 0.0 <= HMR_2947 <= 1000.0
# 0.0 <= HMR_2947_reverse_3e1bf <= 1000.0
# 0.0 <= HMR_3688 <= 1000.0
# 0.0 <= HMR_3688_reverse_6d1fe <= 0.0
# 0.0 <= EX_M00117[e] <= 1000.0
# 0.0 <= EX_M00117[e]_reverse_aa529 <= 1000.0
# 0.0 <= HMR_2282 <= 1000.0
# 0.0 <= HMR_2282_reverse_aaecf <= 0.0
# 0.0 <= HMR_2614 <= 1000.0
# 0.0 <= HMR_2614_reverse_29582 <= 1000.0
# 0.0 <= HMR_0490 <= 1000.0
# 0.0 <= HMR_0490_reverse_d2cd4 <= 0.0
# 0.0 <= HMR_2618 <= 1000.0
# 0.0 <= HMR_2618_reverse_17599 <= 1000.0
# 0.0 <= HMR_3256 <= 1000.0
# 0.0 <= HMR_3256_reverse_a8e47 <= 0.0
# 0.0 <= HMR_3258 <= 1000.0
# 0.0 <= HMR_3258_reverse_5fb0b <= 0.0
# 0.0 <= HMR_3368 <= 1000.0
# 0.0 <= HMR_3368_reverse_79ec6 <= 0.0
# 0.0 <= HMR_3369 <= 1000.0
# 0.0 <= HMR_3369_reverse_44939 <= 0.0
# 0.0 <= RE2914X <= 1000.0
# 0.0 <= RE2914X_reverse_6933d <= 1000.0
# 0.0 <= HMR_2796 <= 1000.0
# 0.0 <= HMR_2796_reverse_d5b96 <= 1000.0
# 0.0 <= HMR_3629 <= 1000.0
# 0.0 <= HMR_3629_reverse_066d5 <= 0.0
# 0.0 <= HMR_0413 <= 1000.0
# 0.0 <= HMR_0413_reverse_bfe4a <= 1000.0
# 0.0 <= HMR_2395 <= 1000.0
# 0.0 <= HMR_2395_reverse_29289 <= 0.0
# 0.0 <= HMR_0414 <= 1000.0
# 0.0 <= HMR_0414_reverse_4c199 <= 0.0
# 0.0 <= HMR_2759 <= 1000.0
# 0.0 <= HMR_2759_reverse_eac49 <= 1000.0
# 0.0 <= HMR_0538 <= 1000.0
# 0.0 <= HMR_0538_reverse_a30b6 <= 0.0
# 0.0 <= FAEL204 <= 1000.0
# 0.0 <= FAEL204_reverse_9a5db <= 0.0
# 0.0 <= RE3148C <= 1000.0
# 0.0 <= RE3148C_reverse_6caaf <= 0.0
# 0.0 <= HMR_2761 <= 1000.0
# 0.0 <= HMR_2761_reverse_fb7b5 <= 1000.0
# 0.0 <= HMR_3421 <= 1000.0
# 0.0 <= HMR_3421_reverse_a779e <= 0.0
# 0.0 <= FAOXC2242046m <= 1000.0
# 0.0 <= FAOXC2242046m_reverse_1fcb5 <= 0.0
# 0.0 <= HMR_2998 <= 1000.0
# 0.0 <= HMR_2998_reverse_efa29 <= 1000.0
# 0.0 <= HMR_2897 <= 1000.0
# 0.0 <= HMR_2897_reverse_b02f6 <= 1000.0
# 0.0 <= HMR_3677 <= 1000.0
# 0.0 <= HMR_3677_reverse_0cf57 <= 0.0
# 0.0 <= HMR_2726 <= 1000.0
# 0.0 <= HMR_2726_reverse_02482 <= 1000.0
# 0.0 <= HMR_2727 <= 1000.0
# 0.0 <= HMR_2727_reverse_0a2ff <= 1000.0
# 0.0 <= HMR_2867 <= 1000.0
# 0.0 <= HMR_2867_reverse_8fb9c <= 1000.0
# 0.0 <= CLPNDCRNt <= 1000.0
# 0.0 <= CLPNDCRNt_reverse_1c8df <= 1000.0
# 0.0 <= HMR_2729 <= 1000.0
# 0.0 <= HMR_2729_reverse_53d37 <= 1000.0
# 0.0 <= HMR_2868 <= 1000.0
# 0.0 <= HMR_2868_reverse_8c546 <= 1000.0
# 0.0 <= HMR_0365 <= 1000.0
# 0.0 <= HMR_0365_reverse_0dd05 <= 1000.0
# 0.0 <= HMR_2493 <= 1000.0
# 0.0 <= HMR_2493_reverse_5ce51 <= 0.0
# 0.0 <= HMR_2497 <= 1000.0
# 0.0 <= HMR_2497_reverse_75880 <= 0.0
# 0.0 <= HMR_0366 <= 1000.0
# 0.0 <= HMR_0366_reverse_4c810 <= 0.0
# 0.0 <= HMR_0526 <= 1000.0
# 0.0 <= HMR_0526_reverse_189bf <= 0.0
# 0.0 <= HMR_3429 <= 1000.0
# 0.0 <= HMR_3429_reverse_6ce24 <= 0.0
# 0.0 <= HMR_2985 <= 1000.0
# 0.0 <= HMR_2985_reverse_f95e9 <= 1000.0
# 0.0 <= HMR_3665 <= 1000.0
# 0.0 <= HMR_3665_reverse_3b7c8 <= 0.0
# 0.0 <= RE3119R <= 1000.0
# 0.0 <= RE3119R_reverse_4e14d <= 1000.0
# 0.0 <= HMR_2690 <= 1000.0
# 0.0 <= HMR_2690_reverse_1fb38 <= 1000.0
# 0.0 <= HMR_2691 <= 1000.0
# 0.0 <= HMR_2691_reverse_d4f2d <= 1000.0
# 0.0 <= HMR_2845 <= 1000.0
# 0.0 <= HMR_2845_reverse_05a42 <= 1000.0
# 0.0 <= HMR_2692 <= 1000.0
# 0.0 <= HMR_2692_reverse_014b6 <= 1000.0
# 0.0 <= HMR_2846 <= 1000.0
# 0.0 <= HMR_2846_reverse_b512e <= 1000.0
# 0.0 <= HMR_0301 <= 1000.0
# 0.0 <= HMR_0301_reverse_3d069 <= 1000.0
# 0.0 <= HMR_2364 <= 1000.0
# 0.0 <= HMR_2364_reverse_fb0a7 <= 0.0
# 0.0 <= HMR_0302 <= 1000.0
# 0.0 <= HMR_0302_reverse_4a416 <= 0.0
# 0.0 <= HMR_0511 <= 1000.0
# 0.0 <= HMR_0511_reverse_48117 <= 0.0
# 0.0 <= HMR_3413 <= 1000.0
# 0.0 <= HMR_3413_reverse_e1b46 <= 0.0
# 0.0 <= HMR_2970 <= 1000.0
# 0.0 <= HMR_2970_reverse_c71c6 <= 1000.0
# 0.0 <= HMR_3650 <= 1000.0
# 0.0 <= HMR_3650_reverse_ddfbd <= 0.0
# 0.0 <= HMR_2717 <= 1000.0
# 0.0 <= HMR_2717_reverse_2e485 <= 1000.0
# 0.0 <= HMR_2718 <= 1000.0
# 0.0 <= HMR_2718_reverse_52ff0 <= 1000.0
# 0.0 <= HMR_2863 <= 1000.0
# 0.0 <= HMR_2863_reverse_e42b0 <= 1000.0
# 0.0 <= EICOSTETCRNt <= 1000.0
# 0.0 <= EICOSTETCRNt_reverse_6e76d <= 1000.0
# 0.0 <= HMR_2719 <= 1000.0
# 0.0 <= HMR_2719_reverse_95cbc <= 1000.0
# 0.0 <= HMR_2864 <= 1000.0
# 0.0 <= HMR_2864_reverse_8235c <= 1000.0
# 0.0 <= HMR_0357 <= 1000.0
# 0.0 <= HMR_0357_reverse_fd67c <= 1000.0
# 0.0 <= HMR_2482 <= 1000.0
# 0.0 <= HMR_2482_reverse_9f43c <= 0.0
# 0.0 <= HMR_2515 <= 1000.0
# 0.0 <= HMR_2515_reverse_fe10d <= 0.0
# 0.0 <= HMR_0358 <= 1000.0
# 0.0 <= HMR_0358_reverse_5e681 <= 0.0
# 0.0 <= HMR_0524 <= 1000.0
# 0.0 <= HMR_0524_reverse_eb649 <= 0.0
# 0.0 <= HMR_3427 <= 1000.0
# 0.0 <= HMR_3427_reverse_2fee5 <= 0.0
# 0.0 <= HMR_2983 <= 1000.0
# 0.0 <= HMR_2983_reverse_5311e <= 1000.0
# 0.0 <= HMR_3663 <= 1000.0
# 0.0 <= HMR_3663_reverse_890c9 <= 0.0
# 0.0 <= RE3106R <= 1000.0
# 0.0 <= RE3106R_reverse_46e80 <= 1000.0
# 0.0 <= RE3170R <= 1000.0
# 0.0 <= RE3170R_reverse_fd60a <= 0.0
# 0.0 <= HMR_2666 <= 1000.0
# 0.0 <= HMR_2666_reverse_2b32c <= 1000.0
# 0.0 <= HMR_2667 <= 1000.0
# 0.0 <= HMR_2667_reverse_fa958 <= 1000.0
# 0.0 <= HMR_2829 <= 1000.0
# 0.0 <= HMR_2829_reverse_cceca <= 0.0
# 0.0 <= ELAIDCRNt <= 1000.0
# 0.0 <= ELAIDCRNt_reverse_0b5fa <= 1000.0
# 0.0 <= HMR_2668 <= 1000.0
# 0.0 <= HMR_2668_reverse_962c7 <= 1000.0
# 0.0 <= HMR_2830 <= 1000.0
# 0.0 <= HMR_2830_reverse_848c6 <= 0.0
# 0.0 <= HMR_0267 <= 1000.0
# 0.0 <= HMR_0267_reverse_25adf <= 1000.0
# 0.0 <= HMR_2295 <= 1000.0
# 0.0 <= HMR_2295_reverse_8648a <= 0.0
# 0.0 <= HMR_0268 <= 1000.0
# 0.0 <= HMR_0268_reverse_c1e9b <= 0.0
# 0.0 <= HMR_0503 <= 1000.0
# 0.0 <= HMR_0503_reverse_b9093 <= 0.0
# 0.0 <= HMR_3407 <= 1000.0
# 0.0 <= HMR_3407_reverse_df376 <= 0.0
# 0.0 <= HMR_2961 <= 1000.0
# 0.0 <= HMR_2961_reverse_23fe2 <= 1000.0
# 0.0 <= HMR_3642 <= 1000.0
# 0.0 <= HMR_3642_reverse_9fcf2 <= 0.0
# 0.0 <= HMR_0200 <= 1000.0
# 0.0 <= HMR_0200_reverse_dd0ea <= 1000.0
# 0.0 <= HMR_0201 <= 1000.0
# 0.0 <= HMR_0201_reverse_fb2f1 <= 0.0
# 0.0 <= HMR_0199 <= 1000.0
# 0.0 <= HMR_0199_reverse_2a379 <= 0.0
# 0.0 <= HMR_0202 <= 1000.0
# 0.0 <= HMR_0202_reverse_fe75d <= 0.0
# 0.0 <= TTDCEAc <= 1000.0
# 0.0 <= TTDCEAc_reverse_27917 <= 0.0
# 0.0 <= HMR_2946 <= 1000.0
# 0.0 <= HMR_2946_reverse_4a22d <= 1000.0
# 0.0 <= HMR_3687 <= 1000.0
# 0.0 <= HMR_3687_reverse_eec03 <= 0.0
# 0.0 <= EX_ttdcea[e] <= 1000.0
# 0.0 <= EX_ttdcea[e]_reverse_7899b <= 1000.0
# 0.0 <= HMR_2281 <= 1000.0
# 0.0 <= HMR_2281_reverse_21371 <= 0.0
# 0.0 <= HMR_2611 <= 1000.0
# 0.0 <= HMR_2611_reverse_a3660 <= 1000.0
# 0.0 <= HMR_0489 <= 1000.0
# 0.0 <= HMR_0489_reverse_4f2f7 <= 0.0
# 0.0 <= HMR_2613 <= 1000.0
# 0.0 <= HMR_2613_reverse_660ea <= 1000.0
# 0.0 <= HMR_3398 <= 1000.0
# 0.0 <= HMR_3398_reverse_1c8f7 <= 0.0
# 0.0 <= HMR_2794 <= 1000.0
# 0.0 <= HMR_2794_reverse_2bfbf <= 1000.0
# 0.0 <= HMR_3628 <= 1000.0
# 0.0 <= HMR_3628_reverse_6896f <= 0.0
# 0.0 <= HMR_2924 <= 1000.0
# 0.0 <= HMR_2924_reverse_71cd8 <= 1000.0
# 0.0 <= HMR_2925 <= 1000.0
# 0.0 <= HMR_2925_reverse_acfbf <= 1000.0
# 0.0 <= TETTET6CRNt <= 1000.0
# 0.0 <= TETTET6CRNt_reverse_3dddc <= 1000.0
# 0.0 <= HMR_2926 <= 1000.0
# 0.0 <= HMR_2926_reverse_1f3ad <= 1000.0
# 0.0 <= HMR_0417 <= 1000.0
# 0.0 <= HMR_0417_reverse_d65cc <= 1000.0
# 0.0 <= HMR_2401 <= 1000.0
# 0.0 <= HMR_2401_reverse_177cb <= 0.0
# 0.0 <= HMR_0418 <= 1000.0
# 0.0 <= HMR_0418_reverse_4a50b <= 0.0
# 0.0 <= HMR_0539 <= 1000.0
# 0.0 <= HMR_0539_reverse_c459e <= 0.0
# 0.0 <= HMR_3025 <= 1000.0
# 0.0 <= HMR_3025_reverse_46c17 <= 1000.0
# 0.0 <= FAOXC2442246x <= 1000.0
# 0.0 <= FAOXC2442246x_reverse_0b64c <= 0.0
# 0.0 <= HMR_2999 <= 1000.0
# 0.0 <= HMR_2999_reverse_aa680 <= 1000.0
# 0.0 <= HMR_3678 <= 1000.0
# 0.0 <= HMR_3678_reverse_34fda <= 0.0
# 0.0 <= HMR_0416 <= 1000.0
# 0.0 <= HMR_0416_reverse_22580 <= 0.0
# 0.0 <= HMR_0419 <= 1000.0
# 0.0 <= HMR_0419_reverse_1090a <= 0.0
# 0.0 <= HMR_3737 <= 1000.0
# 0.0 <= HMR_3737_reverse_1527d <= 0.0
# 0.0 <= EX_tettet6[e] <= 1000.0
# 0.0 <= EX_tettet6[e]_reverse_23270 <= 1000.0
# 0.0 <= HMR_2921 <= 1000.0
# 0.0 <= HMR_2921_reverse_25864 <= 1000.0
# 0.0 <= HMR_2922 <= 1000.0
# 0.0 <= HMR_2922_reverse_67005 <= 1000.0
# 0.0 <= TETPENT3CRNt <= 1000.0
# 0.0 <= TETPENT3CRNt_reverse_1d99c <= 1000.0
# 0.0 <= HMR_2923 <= 1000.0
# 0.0 <= HMR_2923_reverse_87f6b <= 1000.0
# 0.0 <= HMR_0369 <= 1000.0
# 0.0 <= HMR_0369_reverse_e9e81 <= 1000.0
# 0.0 <= HMR_2503 <= 1000.0
# 0.0 <= HMR_2503_reverse_cc60c <= 0.0
# 0.0 <= HMR_0370 <= 1000.0
# 0.0 <= HMR_0370_reverse_5bbe8 <= 0.0
# 0.0 <= HMR_0527 <= 1000.0
# 0.0 <= HMR_0527_reverse_4cce6 <= 0.0
# 0.0 <= HMR_3024 <= 1000.0
# 0.0 <= HMR_3024_reverse_e405e <= 1000.0
# 0.0 <= FAOXC2452253x <= 1000.0
# 0.0 <= FAOXC2452253x_reverse_f2ce2 <= 0.0
# 0.0 <= HMR_2986 <= 1000.0
# 0.0 <= HMR_2986_reverse_64466 <= 1000.0
# 0.0 <= HMR_3666 <= 1000.0
# 0.0 <= HMR_3666_reverse_aedaf <= 0.0
# 0.0 <= HMR_0368 <= 1000.0
# 0.0 <= HMR_0368_reverse_00852 <= 0.0
# 0.0 <= HMR_0371 <= 1000.0
# 0.0 <= HMR_0371_reverse_2f689 <= 0.0
# 0.0 <= HMR_3725 <= 1000.0
# 0.0 <= HMR_3725_reverse_b5da2 <= 0.0
# 0.0 <= EX_tetpent3[e] <= 1000.0
# 0.0 <= EX_tetpent3[e]_reverse_17aeb <= 1000.0
# 0.0 <= HMR_7287 <= 1000.0
# 0.0 <= HMR_7287_reverse_4b130 <= 0.0
# 0.0 <= HMR_7288 <= 1000.0
# 0.0 <= HMR_7288_reverse_97c3b <= 0.0
# 0.0 <= HMR_7289 <= 1000.0
# 0.0 <= HMR_7289_reverse_7f7c5 <= 0.0
# 0.0 <= HMR_7290 <= 1000.0
# 0.0 <= HMR_7290_reverse_99379 <= 0.0
# 0.0 <= HMR_7286 <= 1000.0
# 0.0 <= HMR_7286_reverse_30dc7 <= 0.0
# 0.0 <= HMR_7285 <= 1000.0
# 0.0 <= HMR_7285_reverse_bd5f0 <= 0.0
# 0.0 <= HMR_7428 <= 1000.0
# 0.0 <= HMR_7428_reverse_fdd8f <= 0.0
# 0.0 <= HMR_7578 <= 1000.0
# 0.0 <= HMR_7578_reverse_7dfcb <= 0.0
# 0.0 <= HMR_7587 <= 1000.0
# 0.0 <= HMR_7587_reverse_897c6 <= 0.0
# 0.0 <= HMR_7427 <= 1000.0
# 0.0 <= HMR_7427_reverse_8e574 <= 0.0
# 0.0 <= HMR_7320 <= 1000.0
# 0.0 <= HMR_7320_reverse_99f58 <= 0.0
# 0.0 <= HMR_7321 <= 1000.0
# 0.0 <= HMR_7321_reverse_36d2b <= 0.0
# 0.0 <= HMR_7322 <= 1000.0
# 0.0 <= HMR_7322_reverse_33070 <= 0.0
# 0.0 <= HMR_7323 <= 1000.0
# 0.0 <= HMR_7323_reverse_009c7 <= 0.0
# 0.0 <= HMR_7316 <= 1000.0
# 0.0 <= HMR_7316_reverse_f542f <= 0.0
# 0.0 <= HMR_7317 <= 1000.0
# 0.0 <= HMR_7317_reverse_b73e3 <= 0.0
# 0.0 <= HMR_7318 <= 1000.0
# 0.0 <= HMR_7318_reverse_a7f15 <= 0.0
# 0.0 <= HMR_7315 <= 1000.0
# 0.0 <= HMR_7315_reverse_712d4 <= 0.0
# 0.0 <= HMR_7319 <= 1000.0
# 0.0 <= HMR_7319_reverse_bab91 <= 0.0
# 0.0 <= HMR_7310 <= 1000.0
# 0.0 <= HMR_7310_reverse_a4202 <= 0.0
# 0.0 <= HMR_7311 <= 1000.0
# 0.0 <= HMR_7311_reverse_32d5d <= 0.0
# 0.0 <= HMR_7312 <= 1000.0
# 0.0 <= HMR_7312_reverse_8db89 <= 0.0
# 0.0 <= HMR_7313 <= 1000.0
# 0.0 <= HMR_7313_reverse_1058a <= 0.0
# 0.0 <= HMR_7314 <= 1000.0
# 0.0 <= HMR_7314_reverse_43827 <= 0.0
# 0.0 <= HMR_7308 <= 1000.0
# 0.0 <= HMR_7308_reverse_d2fd4 <= 0.0
# 0.0 <= HMR_7300 <= 1000.0
# 0.0 <= HMR_7300_reverse_af98e <= 0.0
# 0.0 <= HMR_7293 <= 1000.0
# 0.0 <= HMR_7293_reverse_b2f80 <= 0.0
# 0.0 <= HMR_7309 <= 1000.0
# 0.0 <= HMR_7309_reverse_5945d <= 0.0
# 0.0 <= HMR_7307 <= 1000.0
# 0.0 <= HMR_7307_reverse_87847 <= 0.0
# 0.0 <= HMR_7281 <= 1000.0
# 0.0 <= HMR_7281_reverse_0110f <= 0.0
# 0.0 <= HMR_5018 <= 1000.0
# 0.0 <= HMR_5018_reverse_1d266 <= 0.0
# 0.0 <= HMR_6021 <= 1000.0
# 0.0 <= HMR_6021_reverse_d4f11 <= 1000.0
# 0.0 <= HMR_6029 <= 1000.0
# 0.0 <= HMR_6029_reverse_b3919 <= 1000.0
# 0.0 <= HMR_6036 <= 1000.0
# 0.0 <= HMR_6036_reverse_db804 <= 1000.0
# 0.0 <= HMR_6041 <= 1000.0
# 0.0 <= HMR_6041_reverse_077f4 <= 1000.0
# 0.0 <= HMR_6045 <= 1000.0
# 0.0 <= HMR_6045_reverse_7ca82 <= 1000.0
# 0.0 <= HMR_6047 <= 1000.0
# 0.0 <= HMR_6047_reverse_fccb9 <= 1000.0
# 0.0 <= HMR_6050 <= 1000.0
# 0.0 <= HMR_6050_reverse_14a80 <= 1000.0
# 0.0 <= HMR_6052 <= 1000.0
# 0.0 <= HMR_6052_reverse_21d70 <= 1000.0
# 0.0 <= HMR_6053 <= 1000.0
# 0.0 <= HMR_6053_reverse_9941d <= 1000.0
# 0.0 <= HMR_6054 <= 1000.0
# 0.0 <= HMR_6054_reverse_3da37 <= 1000.0
# 0.0 <= HMR_5016 <= 1000.0
# 0.0 <= HMR_5016_reverse_99ea6 <= 0.0
# 0.0 <= HMR_4461 <= 1000.0
# 0.0 <= HMR_4461_reverse_3d105 <= 1000.0
# 0.0 <= HMR_9134 <= 1000.0
# 0.0 <= HMR_9134_reverse_a0898 <= 1000.0
# 0.0 <= HMR_2153 <= 1000.0
# 0.0 <= HMR_2153_reverse_7b93b <= 0.0
# 0.0 <= HMR_2154 <= 1000.0
# 0.0 <= HMR_2154_reverse_83399 <= 0.0
# 0.0 <= HMR_7709 <= 1000.0
# 0.0 <= HMR_7709_reverse_8a7cb <= 1000.0
# 0.0 <= 3HBCOARc <= 1000.0
# 0.0 <= 3HBCOARc_reverse_b4278 <= 1000.0
# 0.0 <= HMR_2165 <= 1000.0
# 0.0 <= HMR_2165_reverse_dc956 <= 0.0
# 0.0 <= HMR_2161 <= 1000.0
# 0.0 <= HMR_2161_reverse_fa863 <= 0.0
# 0.0 <= HMR_2179 <= 1000.0
# 0.0 <= HMR_2179_reverse_a10f1 <= 0.0
# 0.0 <= HMR_4723 <= 1000.0
# 0.0 <= HMR_4723_reverse_088a9 <= 0.0
# 0.0 <= HMR_4725 <= 1000.0
# 0.0 <= HMR_4725_reverse_c0da6 <= 0.0
# 0.0 <= HMR_4730 <= 1000.0
# 0.0 <= HMR_4730_reverse_e5530 <= 1000.0
# 0.0 <= PPNCL3 <= 1000.0
# 0.0 <= PPNCL3_reverse_cd065 <= 0.0
# 0.0 <= HMR_4731 <= 1000.0
# 0.0 <= HMR_4731_reverse_b51e1 <= 1000.0
# 0.0 <= HMR_4733 <= 1000.0
# 0.0 <= HMR_4733_reverse_92fd7 <= 0.0
# 0.0 <= HMR_1448 <= 1000.0
# 0.0 <= HMR_1448_reverse_4a070 <= 1000.0
# 0.0 <= HMR_1451 <= 1000.0
# 0.0 <= HMR_1451_reverse_698b3 <= 0.0
# 0.0 <= HMR_1445 <= 1000.0
# 0.0 <= HMR_1445_reverse_e2957 <= 0.0
# 0.0 <= HMR_3213 <= 1000.0
# 0.0 <= HMR_3213_reverse_2c5b0 <= 0.0
# 0.0 <= HMR_3215 <= 1000.0
# 0.0 <= HMR_3215_reverse_edb16 <= 0.0
# 0.0 <= HMR_3761 <= 1000.0
# 0.0 <= HMR_3761_reverse_083a1 <= 0.0
# 0.0 <= HMR_3763 <= 1000.0
# 0.0 <= HMR_3763_reverse_4fe49 <= 0.0
# 0.0 <= HMR_1440 <= 1000.0
# 0.0 <= HMR_1440_reverse_7a5e0 <= 0.0
# 0.0 <= HMR_1443 <= 1000.0
# 0.0 <= HMR_1443_reverse_042c1 <= 1000.0
# 0.0 <= HMR_4630 <= 1000.0
# 0.0 <= HMR_4630_reverse_b9291 <= 0.0
# 0.0 <= MEVK1x <= 1000.0
# 0.0 <= MEVK1x_reverse_79d3a <= 0.0
# 0.0 <= HMR_3853 <= 1000.0
# 0.0 <= HMR_3853_reverse_b03d4 <= 0.0
# 0.0 <= HMR_3857 <= 1000.0
# 0.0 <= HMR_3857_reverse_475a0 <= 0.0
# 0.0 <= HMR_8502 <= 1000.0
# 0.0 <= HMR_8502_reverse_e6008 <= 1000.0
# 0.0 <= HMR_8510 <= 1000.0
# 0.0 <= HMR_8510_reverse_a62c3 <= 1000.0
# 0.0 <= HMR_8511 <= 1000.0
# 0.0 <= HMR_8511_reverse_ce27c <= 0.0
# 0.0 <= HMR_6970 <= 1000.0
# 0.0 <= HMR_6970_reverse_9a5df <= 1000.0
# 0.0 <= HMR_3245 <= 1000.0
# 0.0 <= HMR_3245_reverse_55247 <= 0.0
# 0.0 <= HMR_3246 <= 1000.0
# 0.0 <= HMR_3246_reverse_64cf9 <= 0.0
# 0.0 <= HMR_3361 <= 1000.0
# 0.0 <= HMR_3361_reverse_44d20 <= 0.0
# 0.0 <= HMR_3362 <= 1000.0
# 0.0 <= HMR_3362_reverse_fcf96 <= 0.0
# 0.0 <= HMR_3785 <= 1000.0
# 0.0 <= HMR_3785_reverse_588da <= 0.0
# ...
# 0.0 <= EX_trpproleu[e] <= 1000.0
# 0.0 <= EX_trpproleu[e]_reverse_58761 <= 1000.0
# 0.0 <= EX_trpproval[e] <= 1000.0
# 0.0 <= EX_trpproval[e]_reverse_c8a64 <= 1000.0
# 0.0 <= EX_trpsertyr[e] <= 1000.0
# 0.0 <= EX_trpsertyr[e]_reverse_f149f <= 1000.0
# 0.0 <= EX_trpthrglu[e] <= 1000.0
# 0.0 <= EX_trpthrglu[e]_reverse_07e8a <= 1000.0
# 0.0 <= EX_trpthrile[e] <= 1000.0
# 0.0 <= EX_trpthrile[e]_reverse_e1992 <= 1000.0
# 0.0 <= EX_trpthrtyr[e] <= 1000.0
# 0.0 <= EX_trpthrtyr[e]_reverse_fb978 <= 1000.0
# 0.0 <= EX_trptyrgln[e] <= 1000.0
# 0.0 <= EX_trptyrgln[e]_reverse_a3ea0 <= 1000.0
# 0.0 <= EX_trptyrtyr[e] <= 1000.0
# 0.0 <= EX_trptyrtyr[e]_reverse_cb468 <= 1000.0
# 0.0 <= EX_trpvalasp[e] <= 1000.0
# 0.0 <= EX_trpvalasp[e]_reverse_8a947 <= 1000.0
# 0.0 <= EX_tyrala[e] <= 1000.0
# 0.0 <= EX_tyrala[e]_reverse_56985 <= 1000.0
# 0.0 <= EX_tyralaphe[e] <= 1000.0
# 0.0 <= EX_tyralaphe[e]_reverse_db964 <= 1000.0
# 0.0 <= EX_tyrargglu[e] <= 1000.0
# 0.0 <= EX_tyrargglu[e]_reverse_d70aa <= 1000.0
# 0.0 <= EX_tyrargser[e] <= 1000.0
# 0.0 <= EX_tyrargser[e]_reverse_7594b <= 1000.0
# 0.0 <= EX_tyrasparg[e] <= 1000.0
# 0.0 <= EX_tyrasparg[e]_reverse_fc96d <= 1000.0
# 0.0 <= EX_tyrcysgly[e] <= 1000.0
# 0.0 <= EX_tyrcysgly[e]_reverse_07b9c <= 1000.0
# 0.0 <= EX_tyrcysthr[e] <= 1000.0
# 0.0 <= EX_tyrcysthr[e]_reverse_ca466 <= 1000.0
# 0.0 <= EX_tyrglu[e] <= 1000.0
# 0.0 <= EX_tyrglu[e]_reverse_69df8 <= 1000.0
# 0.0 <= EX_tyrleuarg[e] <= 1000.0
# 0.0 <= EX_tyrleuarg[e]_reverse_f037e <= 1000.0
# 0.0 <= EX_tyrphetyr[e] <= 1000.0
# 0.0 <= EX_tyrphetyr[e]_reverse_1759a <= 1000.0
# 0.0 <= EX_tyrthr[e] <= 1000.0
# 0.0 <= EX_tyrthr[e]_reverse_27ad0 <= 1000.0
# 0.0 <= EX_tyrtrpphe[e] <= 1000.0
# 0.0 <= EX_tyrtrpphe[e]_reverse_e217a <= 1000.0
# 0.0 <= EX_tyrtyr[e] <= 1000.0
# 0.0 <= EX_tyrtyr[e]_reverse_f8710 <= 1000.0
# 0.0 <= EX_tyrvalmet[e] <= 1000.0
# 0.0 <= EX_tyrvalmet[e]_reverse_2144f <= 1000.0
# 0.0 <= EX_valarggly[e] <= 1000.0
# 0.0 <= EX_valarggly[e]_reverse_09efa <= 1000.0
# 0.0 <= EX_valhisasn[e] <= 1000.0
# 0.0 <= EX_valhisasn[e]_reverse_3429b <= 1000.0
# 0.0 <= EX_valleuphe[e] <= 1000.0
# 0.0 <= EX_valleuphe[e]_reverse_6e4ff <= 1000.0
# 0.0 <= EX_vallystyr[e] <= 1000.0
# 0.0 <= EX_vallystyr[e]_reverse_314ca <= 1000.0
# 0.0 <= EX_valphearg[e] <= 1000.0
# 0.0 <= EX_valphearg[e]_reverse_daede <= 1000.0
# 0.0 <= EX_valprotrp[e] <= 1000.0
# 0.0 <= EX_valprotrp[e]_reverse_fe753 <= 1000.0
# 0.0 <= EX_valserarg[e] <= 1000.0
# 0.0 <= EX_valserarg[e]_reverse_28d10 <= 1000.0
# 0.0 <= EX_valtrpphe[e] <= 1000.0
# 0.0 <= EX_valtrpphe[e]_reverse_44f2d <= 1000.0
# 0.0 <= EX_valtrpval[e] <= 1000.0
# 0.0 <= EX_valtrpval[e]_reverse_b30c7 <= 1000.0
# 0.0 <= EX_valval[e] <= 1000.0
# 0.0 <= EX_valval[e]_reverse_1bfc4 <= 1000.0
# 0.0 <= EX_trpglyasp[e] <= 1000.0
# 0.0 <= EX_trpglyasp[e]_reverse_3d883 <= 1000.0
# 0.0 <= EX_sphmyln_hs[e] <= 1000.0
# 0.0 <= EX_sphmyln_hs[e]_reverse_5b1c6 <= 1000.0
# 0.0 <= EX_acnam[e] <= 1000.0
# 0.0 <= EX_acnam[e]_reverse_20680 <= 1000.0
# 0.0 <= EX_acgal[e] <= 1000.0
# 0.0 <= EX_acgal[e]_reverse_a85ad <= 1000.0
# 0.0 <= EX_glcr[e] <= 1000.0
# 0.0 <= EX_glcr[e]_reverse_5d8b3 <= 1000.0
# 0.0 <= EX_34dhpha[e] <= 1000.0
# 0.0 <= EX_34dhpha[e]_reverse_8a3da <= 1000.0
# 0.0 <= EX_phpyr[e] <= 1000.0
# 0.0 <= EX_phpyr[e]_reverse_07739 <= 1000.0
# 0.0 <= EX_tym[e] <= 1000.0
# 0.0 <= EX_tym[e]_reverse_bed9f <= 1000.0
# 0.0 <= EX_2hyoxplac[e] <= 1000.0
# 0.0 <= EX_2hyoxplac[e]_reverse_96146 <= 1000.0
# 0.0 <= EX_andrstndn[e] <= 1000.0
# 0.0 <= EX_andrstndn[e]_reverse_3f630 <= 1000.0
# 0.0 <= EX_eandrstrn[e] <= 1000.0
# 0.0 <= EX_eandrstrn[e]_reverse_3749c <= 1000.0
# 0.0 <= EX_andrstandn[e] <= 1000.0
# 0.0 <= EX_andrstandn[e]_reverse_d8ff5 <= 1000.0
# 0.0 <= EX_CE2209[e] <= 1000.0
# 0.0 <= EX_CE2209[e]_reverse_61d49 <= 1000.0
# 0.0 <= EX_C05301[e] <= 1000.0
# 0.0 <= EX_C05301[e]_reverse_e9b77 <= 1000.0
# 0.0 <= EX_C05299[e] <= 1000.0
# 0.0 <= EX_C05299[e]_reverse_96c82 <= 1000.0
# 0.0 <= EX_C05302[e] <= 1000.0
# 0.0 <= EX_C05302[e]_reverse_12254 <= 1000.0
# 0.0 <= EX_CE5072[e] <= 1000.0
# 0.0 <= EX_CE5072[e]_reverse_b7b99 <= 1000.0
# 0.0 <= EX_11docrtsl[e] <= 1000.0
# 0.0 <= EX_11docrtsl[e]_reverse_48526 <= 1000.0
# 0.0 <= EX_11docrtstrn[e] <= 1000.0
# 0.0 <= EX_11docrtstrn[e]_reverse_c79d3 <= 1000.0
# 0.0 <= EX_prgnlone[e] <= 1000.0
# 0.0 <= EX_prgnlone[e]_reverse_49f25 <= 1000.0
# 0.0 <= EX_CE2211[e] <= 1000.0
# 0.0 <= EX_CE2211[e]_reverse_2a43e <= 1000.0
# 0.0 <= EX_17ahprgstrn[e] <= 1000.0
# 0.0 <= EX_17ahprgstrn[e]_reverse_4e203 <= 1000.0
# 0.0 <= EX_17ahprgnlone[e] <= 1000.0
# 0.0 <= EX_17ahprgnlone[e]_reverse_c23a4 <= 1000.0
# 0.0 <= EX_C03681[e] <= 1000.0
# 0.0 <= EX_C03681[e]_reverse_9276f <= 1000.0
# 0.0 <= EX_prgnlones[e] <= 1000.0
# 0.0 <= EX_prgnlones[e]_reverse_464ec <= 1000.0
# 0.0 <= EX_CE1352[e] <= 1000.0
# 0.0 <= EX_CE1352[e]_reverse_a4b95 <= 1000.0
# 0.0 <= EX_mma[e] <= 1000.0
# 0.0 <= EX_mma[e]_reverse_bc0d0 <= 1000.0
# 0.0 <= EX_mhista[e] <= 1000.0
# 0.0 <= EX_mhista[e]_reverse_95254 <= 1000.0
# 0.0 <= EX_CE4890[e] <= 1000.0
# 0.0 <= EX_CE4890[e]_reverse_11dde <= 1000.0
# 0.0 <= EX_ppp9[e] <= 1000.0
# 0.0 <= EX_ppp9[e]_reverse_87d2d <= 1000.0
# 0.0 <= EX_mlthf[e] <= 1000.0
# 0.0 <= EX_mlthf[e]_reverse_0e4ee <= 1000.0
# 0.0 <= EX_trypta[e] <= 1000.0
# 0.0 <= EX_trypta[e]_reverse_7a8d7 <= 1000.0
# 0.0 <= EX_selmeth[e] <= 1000.0
# 0.0 <= EX_selmeth[e]_reverse_f0b2b <= 1000.0
# 0.0 <= EX_CE7090[e] <= 1000.0
# 0.0 <= EX_CE7090[e]_reverse_a8400 <= 1000.0
# 0.0 <= EX_CE7085[e] <= 1000.0
# 0.0 <= EX_CE7085[e]_reverse_22928 <= 1000.0
# 0.0 <= EX_CE7096[e] <= 1000.0
# 0.0 <= EX_CE7096[e]_reverse_9cfa4 <= 1000.0
# 0.0 <= EX_CE4877[e] <= 1000.0
# 0.0 <= EX_CE4877[e]_reverse_05d68 <= 1000.0
# 0.0 <= EX_CE1447[e] <= 1000.0
# 0.0 <= EX_CE1447[e]_reverse_7747a <= 1000.0
# 0.0 <= EX_CE2705[e] <= 1000.0
# 0.0 <= EX_CE2705[e]_reverse_d240b <= 1000.0
# 0.0 <= EX_13dampp[e] <= 1000.0
# 0.0 <= EX_13dampp[e]_reverse_2246c <= 1000.0
# 0.0 <= EX_hdd2crn[e] <= 1000.0
# 0.0 <= EX_hdd2crn[e]_reverse_f4650 <= 1000.0
# 0.0 <= EX_N1aspmd[e] <= 1000.0
# 0.0 <= EX_N1aspmd[e]_reverse_a6d7f <= 1000.0
# 0.0 <= EX_CE1918[e] <= 1000.0
# 0.0 <= EX_CE1918[e]_reverse_8f4eb <= 1000.0
# 0.0 <= EX_34dhoxmand[e] <= 1000.0
# 0.0 <= EX_34dhoxmand[e]_reverse_1c448 <= 1000.0
# 0.0 <= EX_CE6205[e] <= 1000.0
# 0.0 <= EX_CE6205[e]_reverse_aa495 <= 1000.0
# 0.0 <= EX_1a25dhvitd3[e] <= 1000.0
# 0.0 <= EX_1a25dhvitd3[e]_reverse_50c39 <= 1000.0
# 0.0 <= EX_CE1617[e] <= 1000.0
# 0.0 <= EX_CE1617[e]_reverse_4fac6 <= 1000.0
# 0.0 <= EX_fdp[e] <= 1000.0
# 0.0 <= EX_fdp[e]_reverse_ef161 <= 1000.0
# 0.0 <= EX_coke[e] <= 1000.0
# 0.0 <= EX_coke[e]_reverse_8b463 <= 1000.0
# 0.0 <= EX_dopa4glcur[e] <= 1000.0
# 0.0 <= EX_dopa4glcur[e]_reverse_1dcc5 <= 1000.0
# 0.0 <= EX_dopa3glcur[e] <= 1000.0
# 0.0 <= EX_dopa3glcur[e]_reverse_c7646 <= 1000.0
# 0.0 <= EX_CE5026[e] <= 1000.0
# 0.0 <= EX_CE5026[e]_reverse_66eba <= 1000.0
# 0.0 <= EX_5cysgly34dhphe[e] <= 1000.0
# 0.0 <= EX_5cysgly34dhphe[e]_reverse_9b9ac <= 1000.0
# 0.0 <= EX_CE5025[e] <= 1000.0
# 0.0 <= EX_CE5025[e]_reverse_29877 <= 1000.0
# 0.0 <= EX_galgluside_hs[e] <= 1000.0
# 0.0 <= EX_galgluside_hs[e]_reverse_0c9e6 <= 1000.0
# 0.0 <= GM1tl <= 1000.0
# 0.0 <= GM1tl_reverse_a0acf <= 0.0
# 0.0 <= GA1tl <= 1000.0
# 0.0 <= GA1tl_reverse_37e88 <= 0.0
# 0.0 <= EX_gd3_hs[e] <= 1000.0
# 0.0 <= EX_gd3_hs[e]_reverse_4c81e <= 1000.0
# 0.0 <= EX_gm3_hs[e] <= 1000.0
# 0.0 <= EX_gm3_hs[e]_reverse_54599 <= 1000.0
# 0.0 <= EX_ga1_hs[e] <= 1000.0
# 0.0 <= EX_ga1_hs[e]_reverse_5d396 <= 1000.0
# 0.0 <= EX_gm1_hs[e] <= 1000.0
# 0.0 <= EX_gm1_hs[e]_reverse_22589 <= 1000.0
# 0.0 <= EX_gm1b_hs[e] <= 1000.0
# 0.0 <= EX_gm1b_hs[e]_reverse_1de33 <= 1000.0
# 0.0 <= EX_gd1a_hs[e] <= 1000.0
# 0.0 <= EX_gd1a_hs[e]_reverse_81308 <= 1000.0
# 0.0 <= EX_gd1b_hs[e] <= 1000.0
# 0.0 <= EX_gd1b_hs[e]_reverse_2b176 <= 1000.0
# 0.0 <= EX_gt1b_hs[e] <= 1000.0
# 0.0 <= EX_gt1b_hs[e]_reverse_af29e <= 1000.0
# 0.0 <= EX_gd2_hs[e] <= 1000.0
# 0.0 <= EX_gd2_hs[e]_reverse_a5d3a <= 1000.0
# 0.0 <= HMR_10023 <= 1000.0
# 0.0 <= HMR_10023_reverse_5647d <= 0.0
# 0.0 <= EX_ca24g[e] <= 1000.0
# 0.0 <= EX_ca24g[e]_reverse_cdf2d <= 1000.0
# 0.0 <= EX_ca3s[e] <= 1000.0
# 0.0 <= EX_ca3s[e]_reverse_b6976 <= 1000.0
# 0.0 <= EX_cdca24g[e] <= 1000.0
# 0.0 <= EX_cdca24g[e]_reverse_bd722 <= 1000.0
# 0.0 <= EX_cdca3g[e] <= 1000.0
# 0.0 <= EX_cdca3g[e]_reverse_2a13a <= 1000.0
# 0.0 <= EX_dca24g[e] <= 1000.0
# 0.0 <= EX_dca24g[e]_reverse_000e4 <= 1000.0
# 0.0 <= EX_dca3g[e] <= 1000.0
# 0.0 <= EX_dca3g[e]_reverse_1ba94 <= 1000.0
# 0.0 <= EX_dca3s[e] <= 1000.0
# 0.0 <= EX_dca3s[e]_reverse_4b605 <= 1000.0
# 0.0 <= EX_gca3s[e] <= 1000.0
# 0.0 <= EX_gca3s[e]_reverse_530de <= 1000.0
# 0.0 <= EX_gcdca3s[e] <= 1000.0
# 0.0 <= EX_gcdca3s[e]_reverse_663bc <= 1000.0
# 0.0 <= EX_gdca3s[e] <= 1000.0
# 0.0 <= EX_gdca3s[e]_reverse_942ff <= 1000.0
# 0.0 <= EX_gudca3s[e] <= 1000.0
# 0.0 <= EX_gudca3s[e]_reverse_03b85 <= 1000.0
# 0.0 <= EX_hca24g[e] <= 1000.0
# 0.0 <= EX_hca24g[e]_reverse_bbb61 <= 1000.0
# 0.0 <= EX_hca6g[e] <= 1000.0
# 0.0 <= EX_hca6g[e]_reverse_a5946 <= 1000.0
# 0.0 <= EX_hdca24g[e] <= 1000.0
# 0.0 <= EX_hdca24g[e]_reverse_945ad <= 1000.0
# 0.0 <= EX_hdca6g[e] <= 1000.0
# 0.0 <= EX_hdca6g[e]_reverse_6002b <= 1000.0
# 0.0 <= EX_hyochol[e] <= 1000.0
# 0.0 <= EX_hyochol[e]_reverse_3aa8d <= 1000.0
# 0.0 <= EX_lca24g[e] <= 1000.0
# 0.0 <= EX_lca24g[e]_reverse_fa60c <= 1000.0
# 0.0 <= EX_lca3g[e] <= 1000.0
# 0.0 <= EX_lca3g[e]_reverse_92c58 <= 1000.0
# 0.0 <= EX_lca3s[e] <= 1000.0
# 0.0 <= EX_lca3s[e]_reverse_71589 <= 1000.0
# 0.0 <= EX_tca3s[e] <= 1000.0
# 0.0 <= EX_tca3s[e]_reverse_dcb5a <= 1000.0
# 0.0 <= EX_tcdca3s[e] <= 1000.0
# 0.0 <= EX_tcdca3s[e]_reverse_0548a <= 1000.0
# 0.0 <= EX_tdca3s[e] <= 1000.0
# 0.0 <= EX_tdca3s[e]_reverse_d40f9 <= 1000.0
# 0.0 <= EX_tudca3s[e] <= 1000.0
# 0.0 <= EX_tudca3s[e]_reverse_4df7f <= 1000.0
# 0.0 <= EX_udca3s[e] <= 1000.0
# 0.0 <= EX_udca3s[e]_reverse_3570c <= 1000.0
# 0.0 <= 2HATVACIDGLUCitr <= 1000.0
# 0.0 <= 2HATVACIDGLUCitr_reverse_6f76b <= 1000.0
# 0.0 <= EX_2hatvacidgluc[e] <= 1000.0
# 0.0 <= EX_2hatvacidgluc[e]_reverse_56106 <= 1000.0
# 0.0 <= ATVACIDitr <= 1000.0
# 0.0 <= ATVACIDitr_reverse_6f566 <= 1000.0
# 0.0 <= EX_2hatvacid[e] <= 1000.0
# 0.0 <= EX_2hatvacid[e]_reverse_5cddd <= 1000.0
# 0.0 <= EX_2hatvlac[e] <= 1000.0
# 0.0 <= EX_2hatvlac[e]_reverse_5e584 <= 1000.0
# 0.0 <= EX_35dhpvs[e] <= 1000.0
# 0.0 <= EX_35dhpvs[e]_reverse_6905d <= 1000.0
# 0.0 <= SMVitr <= 1000.0
# 0.0 <= SMVitr_reverse_6ba52 <= 1000.0
# 0.0 <= 3HPVSCOAitm <= 1000.0
# 0.0 <= 3HPVSCOAitm_reverse_f37b5 <= 1000.0
# 0.0 <= 3HPVSCOAitx <= 1000.0
# 0.0 <= 3HPVSCOAitx_reverse_6f5a3 <= 1000.0
# 0.0 <= 3HPVSTETtev <= 1000.0
# 0.0 <= 3HPVSTETtev_reverse_4031b <= 1000.0
# 0.0 <= EX_3hpvstet[e] <= 1000.0
# 0.0 <= EX_3hpvstet[e]_reverse_a1ecd <= 1000.0
# 0.0 <= EX_3hpvs[e] <= 1000.0
# 0.0 <= EX_3hpvs[e]_reverse_0e64c <= 1000.0
# 0.0 <= 3HSMVhep <= 1000.0
# 0.0 <= 3HSMVhep_reverse_ba23e <= 0.0
# 0.0 <= EX_3ispvs[e] <= 1000.0
# 0.0 <= EX_3ispvs[e]_reverse_abc1f <= 1000.0
# 0.0 <= ACMPitr <= 1000.0
# 0.0 <= ACMPitr_reverse_aebee <= 1000.0
# 0.0 <= GLZitr <= 1000.0
# 0.0 <= GLZitr_reverse_1bd19 <= 1000.0
# 0.0 <= EX_4hatvacid[e] <= 1000.0
# 0.0 <= EX_4hatvacid[e]_reverse_23845 <= 1000.0
# 0.0 <= EX_4hatvlac[e] <= 1000.0
# 0.0 <= EX_4hatvlac[e]_reverse_6affa <= 1000.0
# 0.0 <= 56DHPVStev <= 1000.0
# 0.0 <= 56DHPVStev_reverse_d1271 <= 1000.0
# 0.0 <= EX_56dhpvs[e] <= 1000.0
# 0.0 <= EX_56dhpvs[e]_reverse_cb656 <= 1000.0
# 0.0 <= 56EPPVStev <= 1000.0
# 0.0 <= 56EPPVStev_reverse_17738 <= 1000.0
# 0.0 <= EX_56eppvs[e] <= 1000.0
# 0.0 <= EX_56eppvs[e]_reverse_04d19 <= 1000.0
# 0.0 <= FVSitr <= 1000.0
# 0.0 <= FVSitr_reverse_b5c78 <= 1000.0
# 0.0 <= EX_6epvs[e] <= 1000.0
# 0.0 <= EX_6epvs[e]_reverse_dd122 <= 1000.0
# 0.0 <= 6HLVSTitr <= 1000.0
# 0.0 <= 6HLVSTitr_reverse_da4ea <= 1000.0
# 0.0 <= ISOLVSTAChep <= 1000.0
# 0.0 <= ISOLVSTAChep_reverse_75ff8 <= 0.0
# 0.0 <= 6MELVSTitr <= 1000.0
# 0.0 <= 6MELVSTitr_reverse_67bd6 <= 1000.0
# 0.0 <= EX_6melvacid[e] <= 1000.0
# 0.0 <= EX_6melvacid[e]_reverse_ee044 <= 1000.0
# 0.0 <= 7HPVStev <= 1000.0
# 0.0 <= 7HPVStev_reverse_4b366 <= 1000.0
# 0.0 <= EX_7hpvs[e] <= 1000.0
# 0.0 <= EX_7hpvs[e]_reverse_e8372 <= 1000.0
# 0.0 <= ACMPdt <= 1000.0
# 0.0 <= ACMPdt_reverse_a975a <= 1000.0
# 0.0 <= EX_acmp[e] <= 1000.0
# 0.0 <= EX_acmp[e]_reverse_3e0b9 <= 1000.0
# 0.0 <= CSAtd <= 1000.0
# 0.0 <= CSAtd_reverse_9d100 <= 1000.0
# 0.0 <= EX_atvacid[e] <= 1000.0
# 0.0 <= EX_atvacid[e]_reverse_0431a <= 1000.0
# 0.0 <= EX_atvlac[e] <= 1000.0
# 0.0 <= EX_atvlac[e]_reverse_056dd <= 1000.0
# 0.0 <= CRVSM24itr <= 1000.0
# 0.0 <= CRVSM24itr_reverse_45a4e <= 1000.0
# 0.0 <= CRVS1tev <= 1000.0
# 0.0 <= CRVS1tev_reverse_9dadf <= 1000.0
# 0.0 <= EX_crvsm1[e] <= 1000.0
# 0.0 <= EX_crvsm1[e]_reverse_af697 <= 1000.0
# 0.0 <= CRVStu <= 1000.0
# 0.0 <= CRVStu_reverse_09db5 <= 1000.0
# 0.0 <= EX_crvs[e] <= 1000.0
# 0.0 <= EX_crvs[e]_reverse_df50d <= 1000.0
# 0.0 <= CRVSitr <= 1000.0
# 0.0 <= CRVSitr_reverse_48548 <= 1000.0
# 0.0 <= CRVSM23tev <= 1000.0
# 0.0 <= CRVSM23tev_reverse_d6d2c <= 1000.0
# 0.0 <= EX_crvsm23[e] <= 1000.0
# 0.0 <= EX_crvsm23[e]_reverse_21828 <= 1000.0
# 0.0 <= EX_crvsm24[e] <= 1000.0
# 0.0 <= EX_crvsm24[e]_reverse_ef443 <= 1000.0
# 0.0 <= EX_csa[e] <= 1000.0
# 0.0 <= EX_csa[e]_reverse_68a8d <= 1000.0
# 0.0 <= FVSitx <= 1000.0
# 0.0 <= FVSitx_reverse_937fd <= 1000.0
# 0.0 <= GLZtd <= 1000.0
# 0.0 <= GLZtd_reverse_e8132 <= 1000.0
# 0.0 <= DSPVStev <= 1000.0
# 0.0 <= DSPVStev_reverse_2c6db <= 1000.0
# 0.0 <= EX_dspvs[e] <= 1000.0
# 0.0 <= EX_dspvs[e]_reverse_4d62b <= 1000.0
# 0.0 <= EX_fvs[e] <= 1000.0
# 0.0 <= EX_fvs[e]_reverse_cd61a <= 1000.0
# 0.0 <= EX_glz[e] <= 1000.0
# 0.0 <= EX_glz[e]_reverse_64514 <= 1000.0
# 0.0 <= IBUP_Rtdu <= 1000.0
# 0.0 <= IBUP_Rtdu_reverse_8dc8c <= 1000.0
# 0.0 <= EX_ibup_R[e] <= 1000.0
# 0.0 <= EX_ibup_R[e]_reverse_0ca9b <= 1000.0
# 0.0 <= EX_isolvstacid[e] <= 1000.0
# 0.0 <= EX_isolvstacid[e]_reverse_42c5a <= 1000.0
# 0.0 <= LSTNtd <= 1000.0
# 0.0 <= LSTNtd_reverse_64065 <= 1000.0
# 0.0 <= EX_lstn[e] <= 1000.0
# 0.0 <= EX_lstn[e]_reverse_87f9d <= 1000.0
# 0.0 <= LVSTtu <= 1000.0
# 0.0 <= LVSTtu_reverse_ee16a <= 1000.0
# 0.0 <= EX_lvst[e] <= 1000.0
# 0.0 <= EX_lvst[e]_reverse_61a97 <= 1000.0
# 0.0 <= MDZtd <= 1000.0
# 0.0 <= MDZtd_reverse_6304d <= 1000.0
# 0.0 <= EX_mdz[e] <= 1000.0
# 0.0 <= EX_mdz[e]_reverse_d7eff <= 1000.0
# 0.0 <= EX_ndersv[e] <= 1000.0
# 0.0 <= EX_ndersv[e]_reverse_277c0 <= 1000.0
# 0.0 <= EX_ptvst[e] <= 1000.0
# 0.0 <= EX_ptvst[e]_reverse_8ba29 <= 1000.0
# 0.0 <= EX_ptvstm3[e] <= 1000.0
# 0.0 <= EX_ptvstm3[e]_reverse_e6aaf <= 1000.0
# 0.0 <= EX_pvs[e] <= 1000.0
# 0.0 <= EX_pvs[e]_reverse_30e86 <= 1000.0
# 0.0 <= PVSGLUCtev <= 1000.0
# 0.0 <= PVSGLUCtev_reverse_2ab33 <= 1000.0
# 0.0 <= EX_pvsgluc[e] <= 1000.0
# 0.0 <= EX_pvsgluc[e]_reverse_0a5eb <= 1000.0
# 0.0 <= EX_rsv[e] <= 1000.0
# 0.0 <= EX_rsv[e]_reverse_d5242 <= 1000.0
# 0.0 <= EX_rsvlac[e] <= 1000.0
# 0.0 <= EX_rsvlac[e]_reverse_7ada4 <= 1000.0
# 0.0 <= EX_smv[e] <= 1000.0
# 0.0 <= EX_smv[e]_reverse_0cc7b <= 1000.0
# 0.0 <= SMVACIDtev <= 1000.0
# 0.0 <= SMVACIDtev_reverse_dcccc <= 1000.0
# 0.0 <= EX_smvacid[e] <= 1000.0
# 0.0 <= EX_smvacid[e]_reverse_14ae8 <= 1000.0
# 0.0 <= TACRDtsc <= 1000.0
# 0.0 <= TACRDtsc_reverse_f2591 <= 1000.0
# 0.0 <= EX_tacr[e] <= 1000.0
# 0.0 <= EX_tacr[e]_reverse_d7f8a <= 1000.0
# 0.0 <= EX_tmd[e] <= 1000.0
# 0.0 <= EX_tmd[e]_reverse_faa21 <= 1000.0
# 0.0 <= TRIPVStev <= 1000.0
# 0.0 <= TRIPVStev_reverse_609ad <= 1000.0
# 0.0 <= EX_tripvs[e] <= 1000.0
# 0.0 <= EX_tripvs[e]_reverse_82e8a <= 1000.0
# 0.0 <= IBUP_Sitr <= 1000.0
# 0.0 <= IBUP_Sitr_reverse_a2bf1 <= 1000.0
# 0.0 <= IBUP_Ritr <= 1000.0
# 0.0 <= IBUP_Ritr_reverse_a6d04 <= 1000.0
# 0.0 <= IBUP_Rshep <= 1000.0
# 0.0 <= IBUP_Rshep_reverse_6be0a <= 1000.0
# 0.0 <= LVSTACIDitr <= 1000.0
# 0.0 <= LVSTACIDitr_reverse_41df2 <= 1000.0
# 0.0 <= LVSTitr <= 1000.0
# 0.0 <= LVSTitr_reverse_86662 <= 1000.0
# 0.0 <= EX_lvstacid[e] <= 1000.0
# 0.0 <= EX_lvstacid[e]_reverse_94fb5 <= 1000.0
# 0.0 <= RSVitr <= 1000.0
# 0.0 <= RSVitr_reverse_32b7c <= 1000.0
# 0.0 <= NDERSVitr <= 1000.0
# 0.0 <= NDERSVitr_reverse_258dd <= 1000.0
# 0.0 <= FVSCOAitx <= 1000.0
# 0.0 <= FVSCOAitx_reverse_7aa84 <= 1000.0
# 0.0 <= PTVSTitr <= 1000.0
# 0.0 <= PTVSTitr_reverse_05639 <= 1000.0
# 0.0 <= PTVSTM3itr <= 1000.0
# 0.0 <= PTVSTM3itr_reverse_226d4 <= 1000.0
# 0.0 <= RSVLACitr <= 1000.0
# 0.0 <= RSVLACitr_reverse_187fe <= 1000.0
# 0.0 <= HMR_10024 <= 1000.0
# 0.0 <= HMR_10024_reverse_4832e <= 1000.0
# 0.0 <= HMR_0578 <= 1000.0
# 0.0 <= HMR_0578_reverse_f7a6f <= 0.0
# 0.0 <= HMR_10040 <= 1000.0
# 0.0 <= HMR_10040_reverse_e82fb <= 1000.0
# 0.0 <= HMR_10047 <= 1000.0
# 0.0 <= HMR_10047_reverse_9d0fb <= 1000.0
# -1000.0 <= m02630s[s] <= -0.0
# -1000.0 <= m01965s[s] <= -0.0
# 1.0 <= ess_1 <= 1000.0
# 0 <= ess_1_reverse_bfb8b <= 0
